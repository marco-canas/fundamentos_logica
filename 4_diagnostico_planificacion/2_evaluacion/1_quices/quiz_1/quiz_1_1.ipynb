# %% [markdown]
# # Criterios de diseño de este quiz
#
# Según el cronograma, el **Quiz 1** está programado para el **lunes 11 de agosto de 2025 (S2)**, y debe evaluar los temas de la **semana 1**:
#
# * Sintaxis y semántica de la lógica proposicional.
# * Proposiciones y conectivos lógicos.
# * Reglas de formación.
# * Tablas de verdad (parcialmente: proposiciones simples y compuestas con ¬, ∧, ∨, →, ↔).
#
# ---
#
# # Diseño del Quiz 1 – Fundamentos de Lógica
#
# **Curso:** Licenciatura en Matemáticas – Universidad de Antioquia (Campus Caucasia)
# **Duración:** 30 minutos
# **Fecha:** Lunes 11 de agosto de 2025
# **Valor:** 5% de la nota final (parte de los quices, 20%).
# **Tema:** Lógica proposicional – sintaxis, semántica y tablas de verdad.
#
# ---
#
# ## 📄 Instrucciones
#
# 1. Responda con letra legible.
# 2. Justifique cada respuesta con los procedimientos solicitados.
# 3. No se permite el uso de celulares. Puede usar calculadora científica (Casio 570 o similar).
#
# ---
#
# ## 📝 Preguntas
#
# **1. (2 puntos)**
# Clasifique las siguientes expresiones en **proposiciones** o **no proposiciones**, y justifique:
# a) \$2+3=5\$
# b) ¿Qué hora es?
# c) Si hoy llueve, entonces llevo sombrilla.
# d) El número 7 es par.
#
# ---
#
# **2. (2 puntos)**
# Construya la **tabla de verdad** de la proposición compuesta:
# $(p \land \lnot q) \lor r$
#
# ---
#
# **3. (2 puntos)**
# Dada la proposición:
# $(p \to q) \land (q \to r)$
# a) Interprete su significado en **lenguaje natural**.
# b) Evalúe su valor de verdad cuando $p$ es verdadera, $q$ es falsa y $r$ es verdadera.
#
# ---
#
# **4. (2 puntos)**
# Determine si las proposiciones siguientes son **equivalentes**. Justifique usando tablas de verdad:
# a) $p \to q$
# b) $\lnot p \lor q$
#
# ---
#
# **5. (2 puntos)**
# Formule en lenguaje simbólico, usando las proposiciones:
#
# * $p$: "Hoy es lunes".
# * $q$: "Tenemos clase de Fundamentos de Lógica".
# * $r$: "Hay examen".
#
# La frase:
# *"Si hoy es lunes y tenemos clase, entonces no hay examen."*
#
# ---
#
# 👉 Con este quiz se evalúan los **resultados de aprendizaje iniciales**: distinguir proposiciones, manejar conectivos, elaborar tablas de verdad, interpretar proposiciones en lenguaje natural, y formular en notación simbólica.
#
# ---
#
# ¿Quieres que te prepare también la **rúbrica de calificación detallada** (criterios por pregunta), o prefieres que la deje abierta para que la definas según el desempeño de los estudiantes?

# %%
"""
Generador de .docx para Quiz 1 - Fundamentos de Lógica
Guarda: quiz1_fundamentos_logica.docx
Requisitos: pip install python-docx
"""

from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

def add_heading(document, text, level=1):
    h = document.add_heading(level=level)
    run = h.add_run(text)
    run.bold = True
    return h

def add_paragraph(document, text, bold=False, italic=False, size=11, align='left'):
    p = document.add_paragraph()
    run = p.add_run(text)
    run.bold = bold
    run.italic = italic
    run.font.size = Pt(size)
    if align == 'center':
        p.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
    return p

def main():
    doc = Document()

    # Estilos generales (títulos)
    title = "Quiz 1 — Fundamentos de Lógica"
    subtitle = "Licenciatura en Matemáticas — Facultad de Educación (Campus Caucasia)"
    add_heading(doc, title, level=1)
    add_paragraph(doc, subtitle, size=10, italic=True, align='center')
    add_paragraph(doc, "")  # línea en blanco

    # Metadata
    add_paragraph(doc, "Duración: 30 minutos", bold=False)
    add_paragraph(doc, "Fecha: Lunes 11 de agosto de 2025", bold=False)
    add_paragraph(doc, "Valor: 5% de la nota final", bold=False)
    add_paragraph(doc, "Instrucciones:", bold=True)
    add_paragraph(doc, "1. Responda con letra legible.")
    add_paragraph(doc, "2. Justifique cada respuesta con los procedimientos solicitados.")
    add_paragraph(doc, "3. No se permite el uso de celulares. Puede usar calculadora científica (Casio 570 o similar).")
    add_paragraph(doc, "")  # línea en blanco

    # Preguntas
    add_paragraph(doc, "Preguntas:", bold=True)

    # Pregunta 1
    q1_title = "1. (2 puntos) Clasifique las siguientes expresiones en proposiciones o no proposiciones, y justifique:"
    add_paragraph(doc, q1_title, bold=True)
    add_paragraph(doc, "a) 2 + 3 = 5")
    add_paragraph(doc, "b) ¿Qué hora es?")
    add_paragraph(doc, "c) Si hoy llueve, entonces llevo sombrilla.")
    add_paragraph(doc, "d) El número 7 es par.")
    add_paragraph(doc, "")  # espacio

    # Pregunta 2
    q2_title = "2. (2 puntos) Construya la tabla de verdad de la proposición compuesta:"
    add_paragraph(doc, q2_title, bold=True)
    # Mostrar la fórmula con Unicode
    formula_q2 = "(p ∧ ¬q) ∨ r"
    add_paragraph(doc, f"Fórmula: {formula_q2}")
    add_paragraph(doc, "Construya la tabla de verdad completa (liste todas las combinaciones de p, q, r).")
    add_paragraph(doc, "")  # espacio

    # Pregunta 3
    q3_title = "3. (2 puntos)"
    add_paragraph(doc, q3_title, bold=True)
    add_paragraph(doc, "Dada la proposición:")
    add_paragraph(doc, "(p → q) ∧ (q → r)")
    add_paragraph(doc, "a) Interprete su significado en lenguaje natural.")
    add_paragraph(doc, "b) Evalúe su valor de verdad cuando p = V, q = F, r = V.")
    add_paragraph(doc, "")  # espacio

    # Pregunta 4
    q4_title = "4. (2 puntos) Determine si las proposiciones siguientes son equivalentes. Justifique usando tablas de verdad:"
    add_paragraph(doc, q4_title, bold=True)
    add_paragraph(doc, "a) p → q")
    add_paragraph(doc, "b) ¬p ∨ q")
    add_paragraph(doc, "")  # espacio

    # Pregunta 5
    q5_title = "5. (2 puntos) Formule en lenguaje simbólico usando:"
    add_paragraph(doc, q5_title, bold=True)
    add_paragraph(doc, "- p: \"Hoy es lunes\"")
    add_paragraph(doc, "- q: \"Tenemos clase de Fundamentos de Lógica\"")
    add_paragraph(doc, "- r: \"Hay examen\"")
    add_paragraph(doc, "La frase: \"Si hoy es lunes y tenemos clase, entonces no hay examen.\"")
    add_paragraph(doc, "")
    add_paragraph(doc, "-----------------------------------------------")
    add_paragraph(doc, "¡Buena suerte!", align='center')

    # Guardar archivo
    filename = "quiz1_fundamentos_logica.docx"
    doc.save(filename)
    print(f"Archivo guardado: {filename}")

if __name__ == "__main__":
    main()
# Out:
# Archivo guardado: quiz1_fundamentos_logica.docx
