# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/tools_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/tools_numpy.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/fundamentos_logica/blob/main/images/analisis_numerico_2025-05-27.jpeg?raw=true'>

# %% [markdown]
# ## Título de la clase: Proyecto de aula sobre aplicación de la lógica proposicional a los circuitos lógicos. Con ejemplo de compuertas lógicas.
#
# []()

# %% [markdown]
# # 2. Objetivos e indicadores

# %% [markdown]
# 1. "Comprender los operadores lógicos mediante modelado físico y digital",
# 2. "Diseñar circuitos eléctricos análogos a compuertas lógicas",
# 3. "Aplicar principios STEAMS en solución de problemas reales"

# %% [markdown]
# # "Indicadores":
#
# 1. "Construye 3 circuitos eléctricos análogos a compuertas lógicas",
# 2. "Simula operadores booleanos con funciones Python personalizadas",
# 3. "Resuelve problemas usando tablas de verdad en Pandas DataFrame"

# %%
# 3. Mapa conceptual Graphviz (Código para ejecutar en Jupyter)
from graphviz import Digraph

dot = Digraph(comment='STEAMS Logic Circuits')
dot.attr('node', shape='box3d', style='filled', fillcolor='#E0FFFF')
dot.node('A', 'Álgebra Booleana')
dot.node('B', 'Circuitos Eléctricos', shape='cylinder', fillcolor='#FFE4E1')
dot.node('C', 'Compuertas Lógicas', shape='component', fillcolor='#98FB98')
dot.node('D', 'Python\n(Numpy, SymPy)', shape='ellipse', fillcolor='#F0E68C')
dot.node('E', 'Visualización\n(Matplotlib/Plotly)', shape='tab', fillcolor='#DDA0DD')

dot.edges(['AB', 'AC', 'BC'])
dot.edge('C', 'D', label='Simulación', color='red')
dot.edge('D', 'E', label='Animación', style='dashed')

dot.render('C:/Users/marco/Descargas/STEAMS_Logic_Circuits', view=True)
# Out:
# 'C:\\Users\\marco\\Descargas\\STEAMS_Logic_Circuits.pdf'

# %% [markdown]
# **7. Actividades con código Python**:

# %%
# Actividad 1: Simulación de compuerta AND con interfaz interactiva
import ipywidgets as widgets
from IPython.display import display

def electrical_and(p, q):
    return 1 if p and q else 0

input1 = widgets.ToggleButton(description='Switch 1')
input2 = widgets.ToggleButton(description='Switch 2')
output = widgets.Output()

def update_circuit(change):
    with output:
        print(f"💡 Lamp state: {electrical_and(input1.value, input2.value)}")

input1.observe(update_circuit, names='value')
input2.observe(update_circuit, names='value')
display(widgets.VBox([input1, input2, output]))
# Out:
# VBox(children=(ToggleButton(value=False, description='Switch 1'), ToggleButton(value=False, description='Switc…

# %%
# Actividad 2: Simulación de compuerta AND con interfaz interactiva
import ipywidgets as widgets
from IPython.display import display

def electrical_and(p, q):
    return 1 if p or q else 0

input1 = widgets.ToggleButton(description='Switch 1', color = 'green')
input2 = widgets.ToggleButton(description='Switch 2')
output = widgets.Output()

def update_circuit(change):
    with output:
        print(f"💡 Lamp state: {electrical_and(input1.value, input2.value)}")

input1.observe(update_circuit, names='value')
input2.observe(update_circuit, names='value')
display(widgets.VBox([input1, input2, output]))
# Out:
# VBox(children=(ToggleButton(value=False, description='Switch 1'), ToggleButton(value=False, description='Switc…

# %%
# Actividad 1: Simulación de compuerta AND con interfaz interactiva
import ipywidgets as widgets
from IPython.display import display

def electrical_and(p, q):
    return 1 if not p or q else 0

input1 = widgets.ToggleButton(description='Switch 1')
input2 = widgets.ToggleButton(description='Switch 2')
output = widgets.Output()

def update_circuit(change):
    with output:
        print(f"💡 Lamp state: {electrical_and(input1.value, input2.value)}")

input1.observe(update_circuit, names='value')
input2.observe(update_circuit, names='value')
display(widgets.VBox([input1, input2, output]))
# Out:
# VBox(children=(ToggleButton(value=False, description='Switch 1'), ToggleButton(value=False, description='Switc…

# %%
# Actividad 1: Simulación de compuerta AND con interfaz interactiva
import ipywidgets as widgets
from IPython.display import display

def electrical_and(p, q):
    return 1 if (not p or q) and (not q or p) else 0

input1 = widgets.ToggleButton(description='Switch 1')
input2 = widgets.ToggleButton(description='Switch 2')
output = widgets.Output()

def update_circuit(change):
    with output:
        print(f"💡 Lamp state: {electrical_and(input1.value, input2.value)}")

input1.observe(update_circuit, names='value')
input2.observe(update_circuit, names='value')
display(widgets.VBox([input1, input2, output]))
# Out:
# VBox(children=(ToggleButton(value=False, description='Switch 1'), ToggleButton(value=False, description='Switc…

# %% [markdown]
# # La compuerta or exclusivo o XOR

# %%
# Actividad 1: Simulación de compuerta AND con interfaz interactiva
import ipywidgets as widgets
from IPython.display import display

def electrical_and(p, q):
    return 1 if (not p or q) and (not q or p) else 0

input1 = widgets.ToggleButton(description='Switch 1')
input2 = widgets.ToggleButton(description='Switch 2')
output = widgets.Output()

def update_circuit(change):
    with output:
        print(f"💡 Lamp state: {electrical_and(input1.value, input2.value)}")

input1.observe(update_circuit, names='value')
input2.observe(update_circuit, names='value')
display(widgets.VBox([input1, input2, output]))

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)
#
#   * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Apéndice sobre calendarios y coordinaciones
#
# A continuación le envío el horario de la asignatura Cálculo Vectorial
#
# Días:
# Lunes - Hora: 7:00 a 12:00M
# Fechas:
# Febrero: 10-17-24
#  Marzo: 3-10-17-31
# Abril:7-21-28
# Mayo:5-12-19
#
# Agradezco su apoyo, y si presenta alguna dificultad puede contactarme.
#
# Cordialmente,
# Juan Felipe Rivera Hernández
# Contacto: 3106314300

# %% [markdown]
# # Clase de análisis numérico los Martes de 8 a 12 del medio día.
