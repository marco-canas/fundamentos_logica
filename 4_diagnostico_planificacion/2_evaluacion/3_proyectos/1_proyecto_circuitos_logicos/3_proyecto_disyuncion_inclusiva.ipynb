# %% [markdown]
# [Registro de asistencia a asesoría](https://forms.gle/FNg7WMenKvcgEh2T6)

# %% [markdown]
# [Video de apoyo a la lectura de este cuaderno Jupyter](https://www.youtube.com/watch?v=lLKuuK_Ot4c)

# %% [markdown]
# # Proyecto sobre solución de un problema real de control de una cámara de cuidado utilizando la función de disyunción lógica

# %% [markdown]
# ## Redacta la situación real o el problema real
#
# ¿C+omo control a la cámara de acompañamiento para mi hija, ssiendo que quiero que la cuiddemos mi mammá y yo?

# %% [markdown]
# ## Hace una representación concreta de la situación simulando el encendido de la cámara con una bombilla y el contro de ella con dos suiches.

# %% [markdown]
# ## Cocodrile Clips (Pictórica)
