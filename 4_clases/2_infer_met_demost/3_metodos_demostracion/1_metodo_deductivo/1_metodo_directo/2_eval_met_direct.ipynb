# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas y administración de empresas
#
# [Hábitos atómicos](https://github.com/marco-canas/habitos_atomicos/blob/main/13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos/1_13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación oral, de Tareas en cuadernos Jupyter, Quiz o Parcial de selección múltiple o de preguntas cerradas.

# %% [markdown]
# Dame, por favor, un diseño de clase, con el enfoque: STEAMS  y de aprendizaje basado en problemas y proyectos(ABPP); sobre: **"El método de demostración directa y su implementación en la validación de supuestos geométricos en la formación de Licenciados en matemáticas en Caucasia Antioquia."**, siguiendo la estructura:
#
# 1. Título de la clase
# 2. Objetivo de aprendizaje e indicadores de logro de estos objetivos.
# 3.  Un mapa conceptual que resuma la clase elaborado en Graphviz de python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:/Users/marco/Downloads"`. No olvides el parámetro `view = True` para el método `render()` de Graphviz. Para este mapa controla las superposiciones de los nodos con: graph [overlap=false]; // Elimina superposiciones (puede aumentar el espacio)
# graph [overlap="scalexy"]; // Escala el gráfico para evitar overlaps
# graph [overlap="compress"]; // Comprime el grafo sin overlaps
#
# 4. Contenido de la clase
#
# 5. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
#
# 6. Dame elementos históricos y epistemológicos asociados a esta clase, pero contados como un cuento al estilo de un cuentero antioqueño en Colombia. Incluye imágenes de los protagonistas históricos de esta clase.
#
# 7. Actividades de aprendizaje
#      * Incluya actividades de aprendizaje utilizando Calculadora **Casio 991 LA cw**
#      * Incluya también actividades de aprendizaje y modelación de situaciones o problemas reales a través de circuitos lógicos y circuitos digitales o electrónicos utilizando la aplicación portable cocodrilo. [Descarge esta aplicación portable aquí](https://crocodileclips.net/descargar-crocodile-clips/)
#
# 8.  Tarea o actividades de ejercitación y fijación.
#
#
# 9.  Evaluación incluyendo diez proyectos, un ejemplo de quiz y un ejemplo de parcial.
#      * Diseña el quiz con preguntas, donde se pida al estudiante el mostrar la aplicación de las expresiones lógicas en contextos:
#        - Deportivos
#        - Cotidianos
#        - Matemáticas en teoría de números
#        - Matemáticas en geometría euclidiana
#        - Matemática en Cálculo Diferencial.
#        - Económicos.
#      * Actividad de desarrollo de habilidades metacognitivas para hacernos consientes de nuestro propio proceso de aprendizaje y de la importancia de la evaluación continua.
#
# 10. Diseño de actividad de retroalimentación.
#
# 11. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# 12. Incluye apéndice para la clase sobre desarrollo de habilidades para trabajar en equipo y de asertividad y empatía para relacionarnos. También elementos de la inteligencia emocional para presentar pruebas sin temor y sin realizar fraude en ellas.
# 13. Incluye 10 referentes en didáctica de la matemática que estén de acuerdo a la propuesta didáctica de esta clase. Adiciona a estos referentes a Raymond Duval (Representaciones y cambios de representación para la adquisición de conceptos matemáticos) y a Jeannette Wing (Desarrollo del pensamiento computacional). Déjame todos estos referentes ordenados de acuerdo a las normas APA. Déjame todos estos referentes ordenados de acuerdo a las normas APA. Incluye las citaciones a estos referentes a medida que vallas diseñando la clase.
#
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en Python. En particular utiliza para el diseño de clase a NumPy, Pandas, SymPy, Matplotlib.pyplot, Seaborn, Plotly, ipywidgets, matplotlib.animation y Jupyter Notebook.
# Cuando vallas a utilizar SymPy, ten en cuanta la siguiente configuración:
# # Corrección y mejora del código
# from sympy import symbols, Equivalent
# from sympy.logic.boolalg import truth_table
#
# Cada vez que utilices `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la renderización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dólar $ para que VS Code si me renderice estas expresiones del lenguaje latex. Cuando vallas a utilizar ipywidgets ten en cuenta la siguiente importación inicial para garantizar que la visualización interactiva si se renderice en VS Code:
# import numpy as np
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
# from IPython.display import display, clear_output
# from matplotlib.patches import Rectangle
#
# # Configuración inicial para visualización estática
# %matplotlib inline

# %%
# Gestión del guardado de imagenes  

def save_fig(nombre_archivo_imagen):
    import os 
    import matplotlib.pyplot as plt
    ubicacion_para_imagenes = r"C:/Users/marco/Downloads"
    imagen_path = os.path.join(ubicacion_para_imagenes, nombre_archivo_imagen)
    plt.savefig(imagen_path, bbox_inches='tight')

# %% [markdown]
# # **Diseño de Clase STEAM con Enfoque ABPP: "El Método de Demostración Directa en Geometría"**
#
# **1. Título de la Clase:**
# *"Demostración Directa en Geometría: Validando Supuestos con Python y Lógica"*
#
# ---

# %% [markdown]
# ## **2. Objetivos e Indicadores de Logro**
# **Objetivo Principal:**
# Aplicar el método de demostración directa para validar supuestos geométricos, integrando herramientas computacionales (Python, SymPy, Circuitos Lógicos) y enfoques STEAM.
#
# **Indicadores de Logro:**
# - Identifica los pasos de una demostración directa en geometría euclidiana.
# - Modela problemas geométricos usando SymPy y visualizaciones interactivas.
# - Diseña circuitos lógicos en Crocodile Clips que representen proposiciones geométricas.
# - Analiza contextos cotidianos y deportivos aplicando lógica proposicional.
#
# ---

# %% [markdown]
# ## **3. Mapa Conceptual (Graphviz)**

# %%
from graphviz import Digraph

# Crear grafo
graph = Digraph('DemoDirecta', filename='C:/Users/marco/Downloads/demo_directa.gv', format='png')
graph.attr(overlap='scalexy', rankdir='TB', splines='true')

# Nodos principales
graph.node('A', 'Método de Demostración Directa', shape='ellipse', style='filled', color='lightblue2')
graph.node('B', 'STEAM', shape='doubleoctagon', color='gold')
graph.node('C', 'ABPP', shape='box3d', color='coral')

# Subnodos
graph.node('D', 'Geometría Euclidiana', shape='note', color='plum')
graph.node('E', 'Lógica Proposicional', shape='component', color='tan')
graph.node('F', 'Python (SymPy/Matplotlib)', shape='hexagon', color='lightgreen')
graph.node('G', 'Circuitos Lógicos', shape='cds', color='salmon')

# Conexiones
graph.edges(['AB', 'AC', 'AD', 'AE', 'AF', 'AG'])
graph.edge('D', 'E', label='Axiomas → Teoremas', style='dashed')
graph.edge('F', 'G', label='Modelación', color='red:blue')

# Renderizar
graph.render(view=True)
# Out:
# 'C:\\Users\\marco\\Downloads\\demo_directa.gv.png'

# %% [markdown]
# ## **4. Contenido de la Clase**
# ### **4.1. Fundamentos Teóricos**
# - **Demostración Directa:**
#   Dado un supuesto $P \implies Q$, se construye una cadena lógica desde $P$ hasta $Q$ usando axiomas.
#   Ejemplo: *"Si un triángulo es isósceles, entonces tiene dos ángulos iguales."*
#
# - **Herramientas Computacionales:**

# %% [markdown]
#   ```python
#   from sympy import symbols, Implies, Equivalent
#   P, Q = symbols('P Q')
#   demostracion = Implies(P, Q)  # P → Q
#   ```

# %% [markdown]
# ### **4.2. Visualización con Python**
# **Animación de Teorema de Pitágoras:**

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

fig, ax = plt.subplots()
square, = ax.plot([], [], 'r-')
ax.set_xlim(0, 5); ax.set_ylim(0, 5)

def init():
    square.set_data([], [])
    return (square,)

def animate(i):
    x = [0, i, i, 0, 0]
    y = [0, 0, i, i, 0]
    square.set_data(x, y)
    return (square,)

ani = animation.FuncAnimation(fig, animate, frames=5, init_func=init, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ---
#
# ## **5. Canción/Poema**
# **"El Poema del Geómetra"** (Fragmento)
# *"Con regla y compás, trazo mi verdad,*
# *un axioma firme, sin incertidumbre ya.*
# *Python y lógica, mi nuevo compás,*
# *¡Demuestra! ¡No asumas! ¡Que el rigor es paz."*
#
# ---

# %% [markdown]
# ## **6. Historia Epistemológica**
# **Cuento Antioqueño:**
# *"¡Ajá! Pues verán, muchachos... allá por el 300 a.C., un grieto llamado Euclides, más terco que un mulo paisa, se empeñó en escribir *Los Elementos*. ¡Y vaya que lo logró! Con sus cinco postulados, armó más lío que un domingo en la plaza de Caucasia... Pero ¡claro! Sin él, hoy no tendríamos WiFi (que usa geometría hiperbólica, ¡eso sí es *arrecho*!)."*

# %% [markdown]
# **Imagen:**
# [Euclides](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Euclid.jpg/220px-Euclid.jpg)
#
# ---

# %% [markdown]
# ## **7. Actividades**
# ### **7.1. Con Casio 991 LA cw**
# - Calcular ángulos en triángulos usando funciones trigonométricas.
# - Verificar identidades como $\sin^2(x) + \cos^2(x) = 1$.
#
# ### **7.2. Crocodile Clips**
# - Diseñar un circuito que represente $P \land Q \implies R$ (ejemplo: "Si llueve *y* hace frío, entonces llevo sombrilla").
#
# ---

# %% [markdown]
# ## **8. Tareas**
# - Implementar en SymPy la demostración de que "la suma de ángulos internos de un triángulo es 180°".
# - Crear un Jupyter Notebook con animaciones de transformaciones geométricas.
#
# ---

# %% [markdown]
# ## **9. Evaluación**
# **Quiz Ejemplo:**
# - *"En fútbol, si 'toco el balón' (P) y 'estoy en área' (Q), entonces 'es penal' (R). Representa esto en lógica proposicional y simula un circuito en Crocodile."*

# %% [markdown]
# # **Parcial:**
# - Proyecto: *"Modelar el Teorema de Tales usando Matplotlib y validar con SymPy."*
#
# ---

# %% [markdown]
# # Prompt (DeepSeek)
# Y ahora, dame un diseño de parcial para mi Marco Julio Cañas Campillo, para que yo como profesor del curso, les grabe en video cómo resolverlo en el entorno de Cuadernos Jupyter editados en VS Code, para luego montarlo en el Canal de YouTube DiMathData @dimathdata

# %% [markdown]
# ### **Examen Parcial: Fundamentos de Lógica (Versión DiMathData)**
# **Estudiante: Marco Julio Cañas Campillo**
# **Herramientas:** Jupyter Notebook + Python (VS Code)
# **Duración estimada del video:** 25-30 minutos
# **Puntaje total:** 50 puntos
#
# ---

# %% [markdown]
# #### **I. Ejercicios Prácticos en Python** (30 puntos)
# **Notebook 1: Tablas de Verdad Automatizadas**

# %%
import pandas as pd
import itertools

def tabla_verdad(proposicion='p y q -> r'):
    # Generar todas las combinaciones posibles de valores de verdad
    valores = [True, False]
    combinaciones = list(itertools.product(valores, repeat=3)) # posibilidades lógicas
    
    # Crear DataFrame con las combinaciones o posibilidades lógicas 
    df = pd.DataFrame(combinaciones, columns=['p', 'q', 'r'])
    
    # Calcular la proposición compuesta
    if proposicion == 'p y q -> r':
        # p ∧ q → r
        df['p y q'] = df['p'] & df['q']
        df['p y q -> r'] = ~df['p y q'] | df['r'] # Definición alterna del condicional
    # Aquí se pueden agregar más casos para otras proposiciones
    
    return df

# Ejemplo de uso
if __name__ == '__main__':
    # Mostrar tabla con estilo para el video
    df = tabla_verdad()
    print(df.style.highlight_between(color='#ffcccc', 
                                   subset=['p y q -> r'], 
                                   props='background-color: #ffcccc;', 
                                   axis=None, 
                                   left=False, 
                                   right=False))

# %%
tabla_verdad(proposicion='p y q -> r')
# Out:
#        p      q      r  p y q  p y q -> r
# 0   True   True   True   True        True
# 1   True   True  False   True       False
# 2   True  False   True  False        True
# 3   True  False  False  False        True
# 4  False   True   True  False        True
# 5  False   True  False  False        True
# 6  False  False   True  False        True
# 7  False  False  False  False        True

# %% [markdown]
# **Notebook 2: Demostración de Equivalencias**

# %%
# Ejercicio 2 (10 pts)
# Demostrar automáticamente: ¬(p ∨ q) ≡ ¬p ∧ ¬q
from sympy import *

p, q = symbols('p q')
expr1 = Not(Or(p, q))
expr2 = And(Not(p), Not(q))
# Usar equivalencia lógica y mostrar pasos

Equivalent(expr1, expr2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 10
#       7 expr2 = And(Not(p), Not(q))
#       8 # Usar equivalencia lógica y mostrar pasos
# ---> 10 Equivalent(expr1, expr2).evalf()
#
# AttributeError: 'Equivalent' object has no attribute 'evalf'

# %%
import pandas as pd
import itertools
from sympy import symbols, And, Or, Not, Implies, Equivalent
from sympy.logic.boolalg import Boolean

def tabla_verdad_sympy(expresion):
    """
    Genera tabla de verdad para una expresión lógica de SymPy
    
    Args:
        expresion: Expresión lógica de SymPy (ej: Implies(And(p, q), r))
    
    Returns:
        DataFrame con todas las combinaciones y resultado de la expresión
    """
    # Obtener variables ordenadas alfabéticamente
    variables = sorted(list(expresion.free_symbols), key=lambda x: str(x))
    n = len(variables)
    
    # Generar todas las combinaciones de valores de verdad
    combinaciones = list(itertools.product([True, False], repeat=n))
    
    # Crear DataFrame
    df = pd.DataFrame(combinaciones, columns=[str(v) for v in variables])
    
    # Evaluar expresión para cada combinación
    resultados = []
    for vals in combinaciones:
        sustitucion = dict(zip(variables, vals))
        resultados.append(bool(expresion.subs(sustitucion)))
    
    df['Resultado'] = resultados
    return df

def mostrar_tabla(expresion):
    """
    Muestra la tabla de verdad con resaltado para valores False
    """
    df = tabla_verdad_sympy(expresion)
    
    def highlight_false(val):
        return 'background-color: #ffcccc' if val == False else ''
    
    styled = df.style.map(highlight_false, subset=['Resultado'])
    return styled

# Ejemplo de uso
if __name__ == '__main__':
    # Definir variables
    p, q, r = symbols('p q r')
    
    # Crear expresión: (p ∧ q) → r
    expresion = Implies(And(p, q), r)
    
    # Mostrar tabla
    print(mostrar_tabla(expresion))

# %%
mostrar_tabla(Equivalent(expr1, expr2))
# Out:
# <style type="text/css">
# </style>
# <table id="T_702a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_702a8_level0_col0" class="col_heading level0 col0" >p</th>
#       <th id="T_702a8_level0_col1" class="col_heading level0 col1" >q</th>
#       <th id="T_702a8_level0_col2" class="col_heading level0 col2" >Resultado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_702a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_702a8_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_702a8_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_702a8_row0_col2" class="data row0 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_702a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_702a8_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_702a8_row1_col1" class="data row1 col1" >False</td>
# ...

# %% [markdown]
# **Notebook 3: Visualización de Circuitos Lógicos**
#
# Visealice con circuitos lógicos a: $(p ∧ ¬q) ∨ (¬p ∧ r)$ usando Crocodile Clips.

# %% [markdown]
# ---
#
# #### **II. Problema Teórico-Explicativo** (20 puntos)
# **Sección para explicar en pizarra digital:**

# %% [markdown]
# 4. **(12 pts)** Demostración interactiva:
#    - Usar `ipywidgets` para mostrar cómo varía una tabla de verdad al modificar:
#
# $$ \neg(p \lor q) \equiv \neg p \land \neg q $$

# %%
from ipywidgets import interact 
@interact(p=[True, False], q=[True, False])
def demostracion(p, q):
    print(f"¬({p} ∧ {q}) ≡ {not (p and q)}")
    print(f"¬{p} ∨ ¬{q} ≡ { (not p) or (not q)}")
# Out:
# interactive(children=(Dropdown(description='p', options=(True, False), value=True), Dropdown(description='q', …

# %% [markdown]
# 5. **(8 pts)** Explicación conceptual:
#    - Graficar con `matplotlib` el proceso de inferencia:

# %%
# 5. **(8 pts)** Explicación conceptual:  
# Graficar con `matplotlib` el proceso de inferencia:    

import matplotlib.pyplot as plt 
# Diagrama de Modus Ponens
plt.figure(figsize=(8,4))
plt.plot([0,1], [0,0], 'b-', label="p → q") 
plt.plot([1,1], [0,1], 'r--', label="p ∴ q")
plt.legend()

# %% [markdown]
# El gráfico generado por este código representa visualmente la estructura lógica del **Modus Ponens**, una regla fundamental de inferencia. Aquí está la interpretación detallada:
#
# ---
#
# ### **Elementos del Gráfico**
# 1. **Línea azul horizontal (`p → q`)**:
#    - *Eje X*: Representa el paso del tiempo lógico o el flujo del razonamiento.
#    - *De (0,0) a (1,0)*: Simboliza la implicación "Si p, entonces q" como una premisa base que se mantiene constante.
#
# 2. **Línea roja discontinua vertical (`p ∴ q`)**:
#    - *De (1,0) a (1,1)*: Ilustra la aplicación de la regla:
#      - Parte del punto donde se afirma `p` (intersección con la línea azul).
#      - "Salta" verticalmente para concluir `q`.
#
# ---
#
# ### **Interpretación Conceptual**
# - **Punto (0,0)**: Inicio del razonamiento (premisas).
# - **Punto (1,0)**: Confirmación de `p` (segunda premisa).
# - **Punto (1,1)**: Conclusión `q` derivada de las premisas.
#
# **Flecha implícita**: La transición de (1,0) a (1,1) muestra cómo la verdad de `p` "activa" la implicación para obtener `q`.
#
# ---
#
# ### **Limitaciones y Mejoras Sugeridas**
# 1. **Problemas**:
#    - La representación es abstracta y no intuitiva para quienes esperan un diagrama tradicional de inferencia.
#    - Falta etiquetar explícitamente los puntos críticos (ej: marcar (1,0) como "p=True").
#
# 2. **Código mejorado**:
# ```python
# plt.figure(figsize=(10,5))
# plt.plot([0,2], [0,0], 'b-', lw=2, label="Premisa: p → q")
# plt.plot([1,1], [0,1], 'r--', lw=2, label="Conclusión: p ∴ q", marker='o', markersize=8)
# plt.text(0.9, 0.1, 'p=True', fontsize=12, ha='right')
# plt.text(1.1, 0.9, 'q=True', fontsize=12)
# plt.title('Modus Ponens: Estructura de Inferencia', pad=20)
# plt.legend(fontsize=12, loc='upper left')
# plt.axis('off')  # Ocultar ejes para mayor claridad
# plt.show()
# ```
#
# ---
#
# ### **Resultado del Código Mejorado**
# - **Visualización más clara** con:
#   - Puntos marcados donde se afirma `p` y se concluye `q`.
#   - Leyendas explicativas ampliadas.
#   - Eliminación de ejes numéricos para centrarse en la lógica.
#   - Título descriptivo.
#
# Esta versión hace evidente cómo la verdad de `p` (en la línea azul) "dispara" la conclusión `q` (línea roja). ¿Necesitas adaptarla para explicar otras reglas de inferencia?

# %% [markdown]
# ---
#
# ### **Estructura del Video Tutorial**
# 1. **Introducción** (2 min):
#    - Presentación del problema y herramientas
#    - Mostrar el Jupyter Notebook en VS Code
#
# 2. **Desarrollo** (20 min):
#    - Ejercicio 1: Tablas con pandas + styling (6 min)
#    - Ejercicio 2: Sympy para lógica simbólica (7 min)
#    - Ejercicio 3: Schemdraw para circuitos (7 min)
#
# 3. **Cierre** (5 min):
#    - Solución del problema teórico con widgets
#    - Invitación a suscribirse a @DiMathData
#
# ---
#
# ### **Material Adicional para Descarga**
# - Notebook completo en GitHub
# - PDF con soluciones comentadas
# - Dataset de ejemplos para practicar
#
# **Diseñado para DiMathData:**
# ✓ **Visualmente atractivo:** Uso de colores y gráficos
# ✓ **Pedagogía interactiva:** Widgets y animaciones
# ✓ **Componente práctico:** Código ejecutable paso a paso
#
# ¿Quieres que agregue un ejercicio adicional sobre lógica difusa con Python? ¡Dímelo y lo integro!

# %% [markdown]
# # Prompt para el diseño del parcial 1
#
# Dame, por favor, un diseño de parcial 1 de Fundamentos de Lógica, según mi propuesta de enseñanza con al conjugación de los enfoques STEAMS, ABPP, aula invertida implementados con Cuadernos Jupyter, Lenguaje Python, Calculadora Casio 991 y el simulador Crocodile Clip. Los temas a evaluar en el parcial son: Lógica proposicional, Las doce reglas de la lógica, según Lina Grajales en su texto "Matemáticas I para ciencias económicas" y los últimos temas a evaluar es reglas de inferencia y método directo de demostración aplicado a Geometría Euclidiana.

# %% [markdown]
# # Parcial para Francisco Javier
#
# Aquí tienes un diseño innovador para el **Parcial 1 de Fundamentos de Lógica**, integrando los enfoques **STEAM**, **ABP (Aprendizaje Basado en Proyectos)**, **aula invertida**, y herramientas tecnológicas como **Jupyter Notebooks**, **Python**, **Calculadora Casio 991** y **Crocodile Clip**.
#
# ---
#
# ### **Parcial 1 – Fundamentos de Lógica**
# **Modalidad:** Híbrida (Presencial (Debe asistir a asesoría el sábado 26 de abril de 8 a 12))
# Asesoría general: Geometría, Vectorial, Lógica, Práctica V y Análisis Numérico
# Saturday, April 26 · 8:00am – 12:00pm
# Time zone: America/Bogota
# Google Meet joining info
# Video call link: https://meet.google.com/rrq-fmsv-fmp
# **Duración:** 90 minutos
# **Puntaje total:** 100 puntos
#
# ---
#
# ## **Sección 1: Lógica Proposicional (30 puntos)**
# **Enfoque STEAM + Python (Jupyter Notebook)**
# - **Ejercicio 1 (15 pts):**
#   Dadas las proposiciones:
#   - $p$: "El triángulo ABC es equilátero"
#   - $q$: "Los ángulos internos miden 60°"
#   - $r$: "El área se calcula con $\frac{\sqrt{3}}{4} L^2$"
#
#   Usando **Python en Jupyter Notebook**, escribir código para evaluar la tabla de verdad de:
#   $$(p \land q) \rightarrow r$$
#
# - **Ejercicio 2 (15 pts):**
#   Simular en **Crocodile Clip** un circuito lógico que represente \( \neg (p \lor q) \leftrightarrow (\neg p \land \neg q) \) (Ley de De Morgan). Explicar el resultado.
#
# ---
#
# ## **Sección 2: Las 12 Reglas de la Lógica (20 puntos)**
# **Enfoque ABP + Calculadora Casio 991**
# - **Ejercicio 3 (10 pts):**
#   Dado el argumento:
#   _"Si un número es divisible por 6, entonces es par. El número 24 es divisible por 6. Por lo tanto, 24 es par."_
#   Identificar las reglas de inferencia usadas (Modus Ponens, etc.) y verificarlas con la **Calculadora Casio 991** (usando su modo de verificación lógica).
#
# - **Ejercicio 4 (10 pts):**
#   Aplicar las **12 reglas de Lina Grajales** para analizar un problema económico:
#   _"Si la demanda aumenta y la oferta se mantiene, entonces los precios suben. La demanda está aumentando. Luego, si la oferta se mantiene, los precios subirán."_
#   Identificar las reglas aplicadas.
#
# ---
#
# ## **Sección 3: Reglas de Inferencia y Demostración en Geometría Euclidiana (50 puntos)**
# **Enfoque Aula Invertida + STEAM**
# - **Ejercicio 5 (20 pts):**
#   Usar el **método directo** para demostrar:
#   _"En todo triángulo rectángulo, la suma de los cuadrados de los catetos es igual al cuadrado de la hipotenusa."_
#   - Usar **Python** (SymPy) para verificar algebraicamente.
#   - Representar en **Crocodile Clip** un modelo del teorema.
#
# - **Ejercicio 6 (30 pts):**
#   **Proyecto ABP (Trabajo en equipo previo al parcial, presentado el día del examen):**
#   Diseñar una demostración visual en **Jupyter Notebook** (usando Matplotlib) de:
#   _"Los ángulos opuestos por el vértice son iguales."_
#   - Incluir código Python para generar la figura.
#   - Explicar las reglas de inferencia usadas en la demostración.
#
# ---
#
# ### **Rúbrica de Evaluación:**
# | **Criterio**               | **Puntos** |
# |----------------------------|-----------|
# | Correcto uso de herramientas (Python, Crocodile, Casio) | 30 |
# | Aplicación de reglas lógicas y rigor en demostraciones | 40 |
# | Creatividad e integración STEAM (geometría + programación) | 20 |
# | Claridad y justificación de pasos | 10 |
#
# ---
#
# ### **Notas:**
# - **Pre-parcial (Aula invertida):** Los estudiantes reciben material interactivo en Jupyter Notebooks para practicar antes del examen.
# - **Durante el parcial:** Combinación de ejercicios prácticos (tecnología) y teóricos (lápiz y papel).
# - **Post-parcial:** Retroalimentación con análisis automatizado (Python) de respuestas comunes.
#
# Este diseño fomenta **pensamiento crítico**, **uso de tecnología** y **aplicación multidisciplinar (STEAM)**. ¿Necesitas ajustes o más detalles en alguna sección?

# %% [markdown]
# # Parcial de Omar
#
# Aquí tienes un **ejemplo de examen parcial** para el curso *"Fundamentos de la Lógica"* dirigido a licenciados en Matemáticas, centrado en **lógica proposicional, reglas de la lógica y reglas de inferencia**. El examen combina problemas teóricos y prácticos, con un enfoque en la aplicación rigurosa de conceptos.
#
# ---
#
# ### **Examen Parcial: Fundamentos de la Lógica**
# **Nombre:** ________________________________________
# **Fecha:** ____________________
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Preguntas conceptuales** *(10 puntos)*
# 1. **(3 pts)** Define los siguientes términos:
#    - **Tautología**
#    - **Contradicción**
#    - **Equivalencia lógica** (usando el concepto de bicondicional).
#
# 2. **(4 pts)** Explica con tus palabras:
#    - ¿Por qué el *Modus Ponens* es una regla de inferencia válida? Da un ejemplo matemático donde se aplique.
#    - ¿Qué diferencia hay entre una **ley lógica** (ej.: Ley de De Morgan) y una **regla de inferencia** (ej.: Silogismo Disyuntivo)?
#
# 3. **(3 pts)** Relaciona las columnas según corresponda:
#    - **a.** \( p \land q \) → \( p \)
#    - **b.** \( \neg (p \lor q) \) ↔ \( \neg p \land \neg q \)
#    - **c.** Si \( p \) → \( q \) y \( p \), entonces \( q \).
#    - **1.** Ley de Simplificación
#    - **2.** Ley de De Morgan
#    - **3.** Modus Ponens
#
# ---
#
# #### **II. Problemas de lógica proposicional** *(20 puntos)*
# 4. **(6 pts)** Dadas las proposiciones:
#    - \( p \): "El número \( n \) es par".
#    - \( q \): "\( n \) es divisible por 3".
#    - \( r \): "\( n \) termina en 0".
#
#    Traduce a lenguaje simbólico y simplifica:
#    - *"Si \( n \) es par y no termina en 0, entonces no es divisible por 3"*.
#
# 5. **(8 pts)** Usa tablas de verdad para determinar si la siguiente fórmula es una **tautología, contradicción o contingencia**:
#    \[
#    (p \lor q) \land (\neg p) \rightarrow q
#    \]
#
# 6. **(6 pts)** Demuestra usando equivalencias lógicas (leyes algebraicas) que:
#    \[
#    \neg (p \rightarrow q) \equiv p \land \neg q
#    \]
#
# ---
#
# #### **III. Reglas de inferencia** *(20 puntos)*
# 7. **(10 pts)** Aplica **reglas de inferencia** para derivar la conclusión a partir de las premisas dadas. Justifica cada paso:
#    - Premisa 1: \( p \rightarrow q \)
#    - Premisa 2: \( \neg r \rightarrow \neg q \)
#    - Premisa 3: \( p \)
#    - Conclusión: \( r \)
#
# 8. **(10 pts)** Construye un **argumento válido** (con 3 premisas y 1 conclusión) relacionado con matemáticas (ej.: teoría de números, geometría) y demuestra su validez usando reglas de inferencia.
#    *Ejemplo de tema: "Si un número es primo mayor que 2, entonces es impar..."*.
#
# ---
#
# ### **Criterios de evaluación:**
# - **Claridad y rigor**: Uso correcto de símbolos y notación.
# - **Aplicación de reglas**: Identificación precisa de leyes lógicas o inferencias.
# - **Originalidad**: En problemas de construcción (ej.: problema 8).
#
# ---
#
# ### **Clave de respuestas (opcional para el docente)**
# 1. **Tautología**: Proposición siempre verdadera. **Contradicción**: Siempre falsa. **Equivalencia**: \( A \leftrightarrow B \) es tautología.
# 2. *Modus Ponens*: Si \( p \rightarrow q \) y \( p \) son verdaderas, \( q \) debe serlo (ej.: Si \( n \) es primo > 2 → \( n \) es impar; \( n = 3 \) → impar).
# 4. \( (p \land \neg r) \rightarrow \neg q \).
# 5. Tautología (ver tabla).
# 6. Usar definición de implicación y De Morgan.
# 7. Usar *Modus Ponens* (Prem1 + Prem3 → \( q \)) y *Modus Tollens* (Prem2 + \( q \) → \( r \)).
#
# ---
#
# **Nota**: Este examen evalúa comprensión teórica, habilidades de simbolización y aplicación de reglas en contextos matemáticos. ¡Adapta los ejercicios según el progreso de tu curso! ¿Necesitas ajustar el nivel de dificultad o agregar otro tema?

# %% [markdown]
# # Parcial de Jair Miguél
#
# Aquí tienes un **segundo diseño de examen parcial** para tu estudiante **Jair Miguél**, enfocado en **lógica proposicional, reglas de inferencia y aplicaciones matemáticas**, pero con un enfoque más desafiante y creativo. Incluye problemas contextualizados y una sección de argumentación crítica:
#
# ---
#
# ### **Examen Parcial: Fundamentos de la Lógica**
# **Nombre: Jair Miguél**
# **Fecha:** ____________________
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Análisis conceptual** *(15 puntos)*
# 1. **(5 pts)** Explica con ejemplos matemáticos:
#    - ¿Por qué la **Ley del Silogismo Hipotético** es fundamental en demostraciones de teoremas? *(Ejemplo: Usa proposiciones sobre números reales)*.
#    - ¿Cómo se relaciona la **Ley de Absorción** con las propiedades de conjuntos?
#
# 2. **(4 pts)** Identifica el error en este "falso" argumento y corrige la regla mal aplicada:
#    - Premisa 1: \( p \rightarrow q \)
#    - Premisa 2: \( \neg p \)
#    - "Conclusión": \( \neg q \) *(¿Qué falacia se cometió?)*.
#
# 3. **(6 pts)** Demuestra que:
#    \[
#    (p \land q) \rightarrow r \equiv p \rightarrow (q \rightarrow r)
#    \]
#    Usa **equivalencias lógicas** (no tablas de verdad).
#
# ---
#
# #### **II. Problemas de aplicación matemática** *(20 puntos)*
# 4. **(8 pts)** En teoría de números:
#    - Define simbólicamente:
#      - \( p \): "\( n \) es múltiplo de 6".
#      - \( q \): "\( n \) es par".
#      - \( r \): "\( n \) es múltiplo de 3".
#    - Demuestra usando **reglas de inferencia** que:
#      *"Si \( n \) es múltiplo de 6, entonces \( n \) es par y múltiplo de 3"*.
#
# 5. **(12 pts)** Para la siguiente afirmación en geometría:
#    - *"Si un cuadrilátero es un rectángulo, entonces tiene ángulos rectos. Si tiene ángulos rectos, entonces es un paralelogramo"*.
#    - **a)** Simboliza las proposiciones y escribe la conclusión lógica.
#    - **b)** Prueba su validez usando **Silogismo Hipotético**.
#    - **c)** ¿Podrías concluir que "todo rectángulo es un paralelogramo"? Justifica.
#
# ---
#
# #### **III. Argumentación y creatividad** *(15 puntos)*
# 6. **(7 pts)** Diseña un **argumento válido** de 4 premisas sobre teoría de grafos (ej.: "Si un grafo es conexo...") y deriva la conclusión paso a paso. Usa al menos 3 reglas de inferencia distintas.
#
# 7. **(8 pts)** **Caso crítico**:
#    - Un alumno afirma: *"La implicación \( p \rightarrow q \) es equivalente a \( \neg p \rightarrow \neg q \)"*.
#    - **a)** Demuestra con un contraejemplo matemático que esto es falso.
#    - **b)** Explica por qué la confusión entre **implicación** y **su contrarecíproca** es común en estudiantes.
#
# ---
#
# ### **Criterios de evaluación para Jair Miguél**:
# - **Profundidad**: Uso de ejemplos matemáticos avanzados (teoría de números/geometría).
# - **Rigor lógico**: Correcta aplicación de reglas y detalle en justificaciones.
# - **Creatividad**: Originalidad en los problemas planteados (ej.: teoría de grafos).
#
# ---
#
# ### **Clave de respuestas (esquema)**
# 1. **Silogismo Hipotético**: Ejemplo con \( a > b \rightarrow b > c \rightarrow a > c \). **Ley de Absorción**: \( p \lor (p \land q) \equiv p \) (similar a \( A \cup (A \cap B) = A \)).
# 2. Falacia de **Negación del Antecedente**. Corrección: No se puede inferir \( \neg q \).
# 3. Usar la equivalencia \( a \rightarrow b \equiv \neg a \lor b \) y propiedades distributivas.
# 4. Premisas: \( p \rightarrow q \), \( p \rightarrow r \). Conclusión: \( p \rightarrow (q \land r) \) (*Simplificación* + *Conjunción*).
# 5. **a)** \( p \rightarrow q \), \( q \rightarrow r \) ∴ \( p \rightarrow r \). **c)** Sí, por transitividad.
# 7. **a)** Contraejemplo: \( p \): "\( n = 2 \)", \( q \): "\( n \) es par". \( \neg p \rightarrow \neg q \) sería falso si \( n = 4 \).
#
# ---
#
# **Diferencial para Jair Miguél**:
# - Problemas **contextualizados en matemáticas superiores** (geometría, teoría de números).
# - Sección de **detección de errores** (falacias comunes).
# - **Creatividad en la construcción de argumentos** (ej.: teoría de grafos).
#
# ¿Quieres ajustar algún problema o agregar un enfoque adicional? ¡Estoy aquí para ayudarte!

# %% [markdown]
# # Parcial 1 de Ariana
#
# Aquí tienes un **diseño de examen parcial personalizado para Ariana**, enfocado en **lógica proposicional, reglas de inferencia y aplicaciones prácticas**, pero con un enfoque más intuitivo y contextualizado en problemas cotidianos y matemáticas básicas. El examen combina rigor lógico con accesibilidad:
#
# ---
#
# ### **Examen Parcial: Fundamentos de la Lógica**
# **Nombre: Ariana**
# **Fecha:** ____________________
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Comprensión conceptual** *(15 puntos)*
# 1. **(4 pts)** Explica con tus palabras y un ejemplo cotidiano:
#    - ¿Qué significa que una proposición sea **contradictoria**? Ejemplo: *"Hoy es miércoles y hoy no es miércoles"*.
#    - ¿Cómo se relaciona la **Ley de Doble Negación** con el lenguaje natural?
#
# 2. **(5 pts)** Relaciona cada regla de inferencia con su aplicación práctica:
#    - **a.** Modus Ponens
#    - **b.** Silogismo Disyuntivo
#    - **c.** Ley de Contraposición
#    - **1.** "Si estudio, paso el examen. Estudié. Por tanto, pasaré el examen".
#    - **2.** "Llueve o hace sol. No llueve. Entonces, hace sol".
#    - **3.** "Si no es domingo, entonces la tienda está abierta. La tienda está cerrada. Luego, es domingo".
#
# 3. **(6 pts)** Simboliza y simplifica esta oración:
#    *"No es cierto que, si Juan viene a la fiesta, entonces María trae el pastel y Pedro no compra refrescos"*.
#
# ---
#
# #### **II. Problemas aplicados** *(20 puntos)*
# 4. **(8 pts)** En un contexto de horarios escolares:
#    - \( p \): "La clase de matemáticas es a las 8 AM".
#    - \( q \): "Llego temprano".
#    - \( r \): "Entro al salón".
#    - Traduce a lógica: *"Si la clase de matemáticas es a las 8 AM y no llego temprano, entonces no entro al salón"*.
#    - Usa **tablas de verdad** para verificar si la proposición es una contingencia.
#
# 5. **(6 pts)** Demuestra usando **equivalencias lógicas** que:
#    \[
#    (p \rightarrow q) \land (q \rightarrow r) \equiv (\neg r \rightarrow \neg p)
#    \]
#
# 6. **(6 pts)** Aplica **reglas de inferencia** para derivar la conclusión:
#    - Premisa 1: Si el número es divisible por 4, entonces es par.
#    - Premisa 2: El número 12 es divisible por 4.
#    - Conclusión: ____________________.
#
# ---
#
# #### **III. Argumentación y creatividad** *(15 puntos)*
# 7. **(7 pts)** Inventa una situación de la vida real (ej.: compras, horarios) y construye un **argumento válido** con 3 premisas y 1 conclusión. Muestra los pasos usando reglas de inferencia.
#
# 8. **(8 pts)** **Caso crítico**:
#    - Un compañero dice: *"Si como sano, entonces bajaré de peso. No bajé de peso. Por eso, no comí sano"*.
#    - **a)** ¿Es válido el argumento? Explica por qué sí o no.
#    - **b)** ¿Qué regla de inferencia o falacia está presente aquí?
#
# ---
#
# ### **Criterios de evaluación para Ariana**:
# - **Claridad**: Uso de ejemplos cotidianos y lenguaje accesible.
# - **Precisión**: Correcta simbolización y aplicación de reglas.
# - **Creatividad**: Construcción de argumentos originales basados en contextos reales.
#
# ---
#
# ### **Clave de respuestas (esquema)**
# 1. **Contradicción**: Proposición siempre falsa. **Doble Negación**: "No es cierto que no voy" ↔ "Voy".
# 2. **a-1**, **b-2**, **c-3**.
# 3. \( \neg (p \rightarrow (q \land \neg r)) \equiv p \land (\neg q \lor r) \).
# 4. \( (p \land \neg q) \rightarrow \neg r \). Contingencia (depende de valores de verdad).
# 5. Usar equivalencia de contrapositiva y transitividad.
# 6. Conclusión: "12 es par" (*Modus Ponens*).
# 8. **a)** No es válido (falacia de **Negación del Consecuente**). **b)** Falta aplicar *Modus Tollens* correctamente.
#
# ---
#
# ### **Diferencial para Ariana**:
# - **Enfoque cotidiano**: Problemas de horarios, decisiones personales, etc.
# - **Menos abstracción**: Evita tecnicismos excesivos; prioriza comprensión intuitiva.
# - **Retroalimentación visual**: En claves, se sugieren ayudas como tablas o diagramas para verificar respuestas.
#
# ¿Quieres ajustar la dificultad o agregar un tema específico que Ariana haya trabajado? ¡Cuéntame!

# %% [markdown]
# # Parcial 1 para Shirlis Saray
#
# ### **Examen Parcial: Fundamentos de la Lógica**
# **Nombre: Shirlis Saray**
# **Fecha:** ____________________
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Análisis conceptual** *(15 puntos)*
# 1. **(5 pts)** Define y contrasta con ejemplos:
#    - **Tautología** vs. **Contingencia** (usa proposiciones matemáticas como ejemplos).
#    - Explica por qué la **Ley de Contraposición** es útil en demostraciones matemáticas.
#
# 2. **(4 pts)** Identifica el error en este argumento y corrige la aplicación de las reglas:
#    - Premisa 1: \( p \lor q \)
#    - Premisa 2: \( \neg p \)
#    - "Conclusión": \( q \land r \) *(¿Qué falta o sobra?)*.
#
# 3. **(6 pts)** Demuestra mediante **equivalencias lógicas** (sin tablas de verdad):
#    \[
#    \neg (p \leftrightarrow q) \equiv (p \land \neg q) \lor (\neg p \land q)
#    \]
#
# ---
#
# #### **II. Problemas de lógica aplicada** *(20 puntos)*
# 4. **(8 pts)** En el contexto de conjuntos numéricos:
#    - \( p \): "\( x \in \mathbb{N} \)".
#    - \( q \): "\( x \) es par".
#    - \( r \): "\( x \) es primo".
#    - Simboliza: *"Si \( x \) es natural y no es par, entonces es primo o no es natural"*.
#    - Evalúa su validez para \( x = 3 \) y \( x = 4 \).
#
# 5. **(6 pts)** Usa **reglas de inferencia** para derivar la conclusión:
#    - Premisa 1: \( \neg q \rightarrow \neg p \)
#    - Premisa 2: \( r \rightarrow p \)
#    - Premisa 3: \( r \)
#    - Conclusión: ____________________.
#
# 6. **(6 pts)** Para la proposición: *"Si un triángulo es equilátero, entonces es isósceles"*:
#    - **a)** Simbolízala y escribe su **contrapositiva**.
#    - **b)** ¿Qué regla de inferencia permite concluir que *"No es isósceles → No es equilátero"*?
#
# ---
#
# #### **III. Argumentación avanzada** *(15 puntos)*
# 7. **(8 pts)** Diseña un **argumento válido** de 4 premisas sobre teoría de conjuntos (ej.: relaciones entre \( A \subseteq B \) y \( B \cap C = \emptyset \)). Deriva la conclusión usando al menos **tres reglas de inferencia** diferentes.
#
# 8. **(7 pts)** **Caso crítico**:
#    - Un estudiante afirma: *"\( p \rightarrow q \) es lo mismo que \( q \rightarrow p \)"*.
#    - **a)** Demuestra con un contraejemplo matemático que esto es falso.
#    - **b)** Explica la importancia de la **direccionalidad** en las implicaciones lógicas.
#
# ---
#
# ### **Criterios de evaluación para Shirlis Saray**:
# - **Precisión técnica**: Uso correcto de simbolización y reglas formales.
# - **Aplicación matemática**: Problemas vinculados a teoría de conjuntos, números y geometría.
# - **Profundidad en justificaciones**: Explicaciones claras y detalladas en demostraciones.
#
# ---
#
# ### **Clave de respuestas (esquema)**
# 1. **Tautología**: Ejemplo: \( p \lor \neg p \). **Contingencia**: \( p \land q \) (depende de \( p \) y \( q \)).
# 2. Error: Conclusión introduce \( r \) sin premisa. Corrección: Concluir solo \( q \) (*Silogismo Disyuntivo*).
# 3. Usar definición de bicondicional y De Morgan.
# 4. \( (p \land \neg q) \rightarrow (r \lor \neg p) \). Para \( x=3 \): Verdadero. Para \( x=4 \): Falso.
# 5. Conclusión: \( q \) (*Modus Tollens* en Prem1 + Prem3, luego *Modus Ponens* con Prem2).
# 6. **a)** \( p \rightarrow q \). Contrapositiva: \( \neg q \rightarrow \neg p \). **b)** *Contraposición*.
# 8. **a)** Contraejemplo: \( p \): "\( n = 2 \)", \( q \): "\( n \) es par". \( q \rightarrow p \) es falso para \( n = 4 \).
#
# ---
#
# ### **Diferencial para Shirlis Saray**:
# - **Enfoque en matemáticas discretas**: Problemas con conjuntos, números y geometría.
# - **Exigencias técnicas**: Demostraciones sin tablas de verdad (solo equivalencias).
# - **Argumentación compleja**: Construcción de argumentos multicapa con múltiples reglas.
#
# **¿Adaptamos algún ejercicio a un tema específico que Shirlis haya trabajado?** ¡Estoy aquí para ajustarlo!

# %% [markdown]
# # Parcial 1 para Liliana Andrea
#
# ### **Examen Parcial 1: Fundamentos de la Lógica**
# **Nombre: Liliana Andrea**
# **Fecha:** ____________________
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Conceptos básicos** *(15 puntos)*
# 1. **(4 pts)** Define con ejemplos:
#    - **Proposición simple** vs. **compuesta** (ejemplo matemático y cotidiano).
#    - **Condicional** (\(p \rightarrow q\)): Explica su tabla de verdad con un caso de la vida real.
#
# 2. **(5 pts)** Relaciona cada ley lógica con su aplicación:
#    - **a.** Ley de Identidad
#    - **b.** Ley de No Contradicción
#    - **c.** Ley del Tercero Excluido
#    - **1.** "Un número es par o no es par"
#    - **2.** "Si \(x = 5\), entonces \(x = 5\)"
#    - **3.** "No puede llover y no llover al mismo tiempo"
#
# 3. **(6 pts)** Simboliza y simplifica:
#    *"Si estudio y hago ejercicios, aprobaré; pero si no estudio, reprobaré"*.
#
# ---
#
# #### **II. Problemas prácticos** *(20 puntos)*
# 4. **(8 pts)** En el contexto de compras:
#    - \(p\): "Compro manzanas"
#    - \(q\): "Compro peras"
#    - \(r\): "Tengo descuento"
#    - Traduce: *"Si compro manzanas o peras, tengo descuento; pero no tengo descuento"*
#    - ¿Qué puedes concluir? Usa **tabla de verdad** o **reglas de inferencia**.
#
# 5. **(6 pts)** Demuestra usando **equivalencias lógicas**:
#    \[
#    \neg(p \lor q) \rightarrow r \equiv (p \lor q) \lor r
#    \]
#
# 6. **(6 pts)** Aplica **inferencia** para resolver:
#    Premisa 1: Si es fin de semana, el cine está lleno
#    Premisa 2: Hoy no es fin de semana
#    Conclusión: __________________________
#
# ---
#
# #### **III. Análisis y creación** *(15 puntos)*
# 7. **(7 pts)** Crea un **argumento válido** sobre hábitos de estudio (3 premisas + conclusión) y muestra los pasos lógicos.
#    Ejemplo:
#    - Si organizo mi tiempo, estudio mejor
#    - Si estudio mejor, obtengo buenas notas
#    - Organizo mi tiempo
#    - ∴ Obtengo buenas notas
#
# 8. **(8 pts)** **Caso de análisis**:
#    - Un compañero dice: *"Si como verduras, estaré sano. Estoy sano, entonces como verduras"*
#    - **a)** ¿Es válido? Explica.
#    - **b)** ¿Qué error lógico cometió?
#
# ---
#
# ### **Criterios de evaluación**:
# ✓ **Claridad**: Explicaciones sencillas pero precisas
# ✓ **Aplicación**: Uso de contextos cotidianos
# ✓ **Rigor**: Correcto uso de simbolización y reglas
#
# ### **Diferencial para Liliana Andrea**:
# - **Enfoque intuitivo**: Problemas de compras, hábitos, etc.
# - **Énfasis en comprensión** sobre memorización
# - **Retroalimentación visual**: Se sugieren diagramas para explicar errores
#
# **Pregunta:** ¿Quieres ajustar algún ejercicio para incluir un tema específico que Liliana haya visto con más profundidad?

# %% [markdown]
# # Parcial 1 Keyla Melisa
#
# ### **Examen Parcial 1: Fundamentos de Lógica**
# **Estudiante: Keyla Melisa**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# ### **I. Comprensión conceptual** (15 puntos)
# 1. **(4 pts)** Explica con ejemplos:
#    - ¿Qué es una **tabla de verdad** y para qué sirve? (Usa una proposición simple)
#    - Diferencia entre **equivalencia lógica** y **implicación lógica**
#
# 2. **(5 pts)** Relaciona cada concepto con su ejemplo correcto:
#    | **Concepto**       | **Ejemplo**                                  |
#    |--------------------|---------------------------------------------|
#    | a) Tautología      | 1) "Hoy llueve o no llueve"                 |
#    | b) Contradicción   | 2) "El número 3 es par y no es par"         |
#    | c) Contingencia    | 3) "Si estudio, aprobaré"                   |
#
# 3. **(6 pts)** Simboliza y simplifica:
#    *"No es cierto que si voy al cine, entonces compro palomitas y no pido refresco"*
#
# ---
#
# ### **II. Aplicación práctica** (20 puntos)
# 4. **(8 pts)** En un contexto de clima:
#    - p: "Llueve"
#    - q: "Llevo paraguas"
#    - r: "Me mojo"
#    a) Traduce: *"Si llueve y no llevo paraguas, entonces me mojo"*
#    b) Construye su tabla de verdad completa
#
# 5. **(6 pts)** Demuestra usando leyes lógicas:
#    ¬(p ∧ q) → r ≡ p → (¬q ∨ r)
#
# 6. **(6 pts)** Aplica inferencia:
#    Premisa 1: Si es invierno, hace frío
#    Premisa 2: No hace frío
#    Conclusión: _______________
#
# ---
#
# ### **III. Análisis crítico** (15 puntos)
# 7. **(7 pts)** Diseña un argumento válido sobre salud (3 premisas + conclusión) usando:
#    - Al menos dos conectivos lógicos diferentes
#    - Una regla de inferencia clara
#
# 8. **(8 pts)** Analiza este argumento:
#    *"Si duermo bien, rindo en el examen. Rendí en el examen, entonces dormí bien"*
#    a) ¿Es válido? Justifica
#    b) Identifica la falacia o regla aplicada
#
# ---
#
# ### **Criterios de evaluación**
# ✔ **Precisión técnica** (simbología correcta)
# ✔ **Razonamiento claro** (pasos lógicos bien explicados)
# ✔ **Originalidad** (en construcción de argumentos)
#
# **Diseñado para Keyla Melisa:**
# - Énfasis en **ejemplos cotidianos** (clima, salud)
# - Combinación de **ejercicios guiados** y **creativos**
# - Incluye **retroalimentación visual sugerida** (tablas, diagramas)

# %% [markdown]
# # Parcial para Angela
#
# ### **Examen Parcial 1: Fundamentos de Lógica**
# **Estudiante: Ángela**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Comprensión conceptual** (15 puntos)
# 1. **(4 pts)** Explica con tus palabras y un ejemplo:
#    - ¿Qué es una **tabla de verdad**? (Usa una proposición compuesta con dos variables)
#    - ¿Por qué la **Ley de De Morgan** es útil para simplificar expresiones?
#
# 2. **(5 pts)** Relaciona cada regla de inferencia con su aplicación correcta:
#    ```
#    a) Modus Ponens        1) "Si es pájaro, vuela. No vuela → No es pájaro"
#    b) Modus Tollens       2) "Si estudio, aprendo. Estudié → Aprendí"
#    c) Silogismo Hipotético 3) "Si llueve, se moja. Si se moja, crece hierba → Si llueve, crece hierba"
#    ```
#
# 3. **(6 pts)** Simboliza y simplifica:
#    *"No es verdad que si apruebo lógica, entonces no estudio o no hago ejercicios"*
#
# ---
#
# #### **II. Aplicación práctica** (20 puntos)
# 4. **(8 pts)** Contexto académico:
#    - p: "Asisto a clases"
#    - q: "Hago tareas"
#    - r: "Apruebo el curso"
#    a) Traduce: *"Asisto a clases y hago tareas solo si apruebo el curso"*
#    b) Evalúa si es tautología, contradicción o contingencia mediante tabla de verdad
#
# 5. **(6 pts)** Demuestra usando equivalencias lógicas:
#    \[
#    (p \rightarrow q) \land (q \rightarrow r) \equiv (\neg r \rightarrow \neg p)
#    \]
#
# 6. **(6 pts)** Aplica **reglas de inferencia** para derivar:
#    Premisa 1: Si es fin de semana, voy al parque
#    Premisa 2: Si voy al parque, llevo merienda
#    Premisa 3: Es fin de semana
#    Conclusión: _______________
#
# ---
#
# #### **III. Análisis y creación** (15 puntos)
# 7. **(7 pts)** Construye un **argumento válido** sobre hábitos saludables (3 premisas + conclusión) que use:
#    - Al menos tres conectivos lógicos diferentes
#    - Dos reglas de inferencia (indica cuáles aplicaste)
#
# 8. **(8 pts)** **Caso crítico**:
#    Un compañero argumenta:
#    *"Si como sano, tengo energía. Tengo energía, entonces como sano"*
#    a) ¿El razonamiento es correcto? Explica.
#    b) Propón un contraejemplo y menciona la falacia presente.
#
# ---
#
# ### **Criterios de evaluación**
# | **Aspecto**          | **Puntaje** |
# |-----------------------|-------------|
# | Claridad conceptual   | 15 pts      |
# | Precisión técnica     | 20 pts      |
# | Creatividad y rigor   | 15 pts      |
#
# ### **Diseñado para Ángela**:
# - **Enfoque pedagógico**: Ejemplos de vida académica y salud para facilitar comprensión.
# - **Dificultad progresiva**: Desde conceptos básicos hasta argumentación compleja.
# - **Retroalimentación visual**: Espacio para tablas de verdad y pasos de demostración.
#
# **Clave de respuestas (esquema)**:
# 1. Ejemplo tabla de verdad: \( p \lor q \). Ley de De Morgan: \( \neg(p \land q) \equiv \neg p \lor \neg q \).
# 3. \( \neg(aprove \rightarrow (\neg estudio \lor \neg ejercicios)) \equiv aprove \land (estudio \land ejercicios) \).
# 6. Conclusión: "Llevo merienda" (Silogismo Hipotético + Modus Ponens).
# 8. a) No (falacia de afirmar el consecuente). b) Contraejemplo: "Tengo energía por dormir bien, no por comer sano".
#
# ¿Necesitas ajustar algún ejercicio o agregar un tema específico que Ángela haya trabajado? ¡Estoy aquí para ayudarte!

# %% [markdown]
# # Parcial de Sandy
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Sandy Janeth Villa Cabarca**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Fundamentos conceptuales** (15 puntos)
# 1. **(4 pts)** Explica con ejemplos propios:
#    - ¿Qué hace que una proposición sea **válida**? (Ejemplo matemático y cotidiano)
#    - Diferencia entre **equivalencia** e **implicación lógica**
#
# 2. **(5 pts)** Relaciona cada ley lógica con su aplicación:
#    ```
#    a) Doble Negación         1) "No es cierto que no aprobaré ↔ Aprobaré"
#    b) Ley de Absorción       2) "p ∧ (p ∨ q) ↔ p"
#    c) Conmutativa           3) "p ∨ q ↔ q ∨ p"
#    ```
#
# 3. **(6 pts)** Simboliza y simplifica:
#    *"Si estudio con dedicación y practico ejercicios, entonces aprenderé; pero si no estudio con dedicación, no aprenderé"*
#
# ---
#
# #### **II. Lógica aplicada** (20 puntos)
# 4. **(8 pts)** Contexto universitario:
#    - p: "Asisto a tutorías"
#    - q: "Entiendo los temas"
#    - r: "Apruebo el parcial"
#    a) Traduce: *"Solo si asisto a tutorías y entiendo los temas, aprobaré el parcial"*
#    b) Construye su tabla de verdad completa
#
# 5. **(6 pts)** Demuestra usando equivalencias:
#    \[
#    (p → q) ∧ (¬p → r) ≡ (q ∨ r)
#    \]
#
# 6. **(6 pts)** Aplica inferencia:
#    Premisa 1: Si es sábado, voy al mercado
#    Premisa 2: Si voy al mercado, compro verduras
#    Premisa 3: No compré verduras
#    Conclusión: _______________
#
# ---
#
# #### **III. Análisis profundo** (15 puntos)
# 7. **(8 pts)** Diseña un **argumento formal** sobre rendimiento académico (4 premisas + conclusión) que incluya:
#    - Uso de al menos tres conectivos diferentes
#    - Aplicación de dos reglas de inferencia (especificar cuáles)
#
# 8. **(7 pts)** Analiza este argumento:
#    *"Todos los lógicos son rigurosos. Sandy es rigurosa. Por tanto, Sandy es lógica"*
#    a) ¿Es válido? Justifica formalmente
#    b) Identifica la estructura lógica y el posible error
#
# ---
#
# ### **Criterios de evaluación**
# | **Habilidad**            | **Puntaje** |
# |--------------------------|-------------|
# | Comprensión conceptual   | 15 pts      |
# | Aplicación técnica       | 20 pts      |
# | Pensamiento crítico      | 15 pts      |
#
# ### **Adecuado para Sandy Janeth**:
# - **Enfoque académico**: Ejemplos relacionados con su contexto universitario
# - **Profundidad progresiva**: Desde conceptos básicos hasta análisis de argumentos complejos
# - **Espacio para desarrollo**: Áreas amplias para demostraciones y tablas
#
# **Clave parcial**:
# 3. Simbolización: (e ∧ p) → a ∧ (¬e → ¬a)
# 6. Conclusión: "No es sábado" (Modus Tollens + Silogismo Hipotético)
# 8. a) No válido (falacia de la afirmación del consecuente)
#
# **¿Necesitas modificar algún ítem para ajustarlo mejor al perfil de Sandy?** Puedo personalizarlo aún más.

# %% [markdown]
# # Parcial 1 Luis Mario
#
# ### **Examen Parcial: Fundamentos de Lógica Matemática**
# **Estudiante: Luis Mario**
# **Fecha:** _______________
# **Duración:** 100 minutos
# **Puntaje total:** 60 puntos
#
# ---
#
# #### **I. Análisis teórico-crítico** (18 puntos)
# 1. **(6 pts)** Demuestre mediante **equivalencias lógicas** (sin tablas de verdad):
#    \[
#    \neg(p \leftrightarrow q) \equiv (p \lor q) \land \neg(p \land q)
#    \]
#    *Incluya una explicación paso a paso de cada transformación aplicada.*
#
# 2. **(6 pts)** Para las proposiciones:
#    - \( p \): "El triángulo ABC es equilátero"
#    - \( q \): "El triángulo ABC es isósceles"
#    a) Formalice: *"Ser equilátero es condición suficiente pero no necesaria para ser isósceles"*
#    b) Demuestre por **contradicción** que \( p \to q \) es siempre verdadera.
#
# 3. **(6 pts)** Analice la validez del siguiente argumento usando **árboles lógicos**:
#    \[
#    \frac{p \to (q \land r), \neg r}{\therefore \neg p}
#    \]
#
# ---
#
# #### **II. Lógica avanzada aplicada** (24 puntos)
# 4. **(8 pts)** En teoría de conjuntos:
#    - \( A \): "Conjunto de números primos"
#    - \( B \): "Conjunto de números impares"
#    - \( C \): "Conjunto de números menores que 10"
#    a) Formalice en lógica de predicados: *"Todo número primo menor que 10 es impar"*
#    b) Demuestre o refute usando álgebra de Boole:
#    \[
#    (A \cap C) \subseteq B
#    \]
#
# 5. **(8 pts)** Para el sistema axiomático:
#    - Axioma 1: \( p \to (q \to p) \)
#    - Axioma 2: \( (p \to (q \to r)) \to ((p \to q) \to (p \to r)) \)
#    - Regla: Modus Ponens
#    Derive formalmente:
#    \[
#    \vdash p \to p
#    \]
#
# 6. **(8 pts)** Resuelva usando **resolución lógica**:
#    \[
#    \frac{(p \lor q) \land (\neg p \lor r) \land (\neg q \lor s)}{\therefore r \lor s}
#    \]
#
# ---
#
# #### **III. Problemas integradores** (18 puntos)
# 7. **(10 pts)** Diseñe un **sistema lógico completo** (lenguaje, axiomas y reglas) para analizar argumentos geométricos que incluya:
#    - Dos conectivos primitivos
#    - Tres axiomas no triviales
#    - Una regla de inferencia no clásica
#    *Justifique cada componente con ejemplos geométricos.*
#
# 8. **(8 pts)** Meta-análisis:
#    Dado el teorema:
#    *"En toda demostración por reducción al absurdo, la negación del antecedente implica una contradicción"*:
#    a) Formalice el enunciado en lógica modal
#    b) Proponga una semántica de Kripke para su interpretación
#
# ---
#
# ### **Criterios de evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Rigor en demostraciones formales | 24 pts      |
# | Creatividad en sistemas lógicos | 18 pts      |
# | Profundidad en análisis        | 18 pts      |
#
# ### **Diseñado para Luis Mario**:
# - **Nivel avanzado**: Problemas de lógica matemática pura
# - **Enfoque axiomático**: Énfasis en sistemas formales y metalógica
# - **Componente investigativo**: Integración de lógica clásica y no clásica
#
# **Clave parcial (esquema):**
# 1. Usar equivalencia del bicondicional y Leyes de De Morgan.
# 4b) Falso (contraejemplo: $2 \in A \cap C$ pero $2 \notin B$).
# 7. Ejemplo: Sistema con conectivos "es congruente" y "es semejante", axiomas de incidencia.
#
# **Nota:** Este examen evalúa competencias propias de un curso avanzado de lógica para matemáticos. ¿Requiere ajustar el nivel de abstracción o incluir otros temas específicos?

# %% [markdown]
# # Parcial 1 de Camilo Andrés Rohenes
#
# ### **Examen Parcial 1: Fundamentos de Lógica Matemática**
# **Estudiante: Camilo Andrés Rohenes**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Conceptos Fundamentales** (15 puntos)
# 1. **(5 pts)** Defina con precisión y ejemplos matemáticos:
#    - **Implicación lógica** vs. **Equivalencia lógica**
#    - **Ley del Silogismo Hipotético** (incluya una demostración algebraica)
#
# 2. **(5 pts)** Relacione cada estructura lógica con su aplicación en demostraciones:
#    ```
#    a) Modus Tollens           1) Demostración por contradicción
#    b) Reducción al absurdo    2) Inferencia indirecta
#    c) Contrapositiva          3) Demostración de negaciones
#    ```
#
# 3. **(5 pts)** Formalice en lógica proposicional:
#    *"Si un número es divisible por 6, entonces es par y divisible por 3, excepto cuando es primo"*
#
# ---
#
# #### **II. Lógica Aplicada a Matemáticas** (20 puntos)
# 4. **(8 pts)** En teoría de números:
#    - \( p \): "\( n \) es múltiplo de 4"
#    - \( q \): "\( n \) es par"
#    - \( r \): "\( n \) termina en 0"
#    a) Demuestre mediante **tabla de verdad extendida** que:
#    \[
#    (p \rightarrow q) \land (q \lor r)
#    \]
#    es una contingencia
#    b) ¿Qué condición debe cumplir \( n \) para que \( p \leftrightarrow q \) sea verdadera?
#
# 5. **(6 pts)** Demuestre usando **equivalencias algebraicas**:
#    \[
#    \neg(p \land q) \rightarrow r \equiv p \rightarrow (\neg q \lor r)
#    \]
#
# 6. **(6 pts)** Aplique **inferencia lógica** para derivar:
#    Premisa 1: Todo cuadrado es rectángulo
#    Premisa 2: Algunos rectángulos son rombos
#    Conclusión: __________________________
#
# ---
#
# #### **III. Análisis Profundo** (15 puntos)
# 7. **(8 pts)** Diseñe un **sistema axiomático mínimo** para lógica geométrica que incluya:
#    - 2 conectivos lógicos primitivos
#    - 3 axiomas sobre relaciones entre figuras
#    - 1 regla de inferencia no convencional
#    *Ejemplifique con teoremas básicos de geometría*
#
# 8. **(7 pts)** Analice críticamente:
#    *"En lógica clásica, \( p \lor \neg p \) es siempre verdadero, pero en intuicionismo no"*
#    a) Formalice ambas posturas
#    b) Proponga un caso geométrico donde sea relevante esta diferencia
#
# ---
#
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Precisión en definiciones      | 15 pts      |
# | Solidez en demostraciones      | 20 pts      |
# | Originalidad en sistemas       | 15 pts      |
#
# ### **Diseñado para Camilo Andrés**:
# - **Enfoque teórico-práctico**: Combina fundamentos con aplicaciones matemáticas
# - **Nivel intermedio-avanzado**: Problemas que requieren abstracción pero con soporte concreto
# - **Componente creativo**: Construcción de sistemas lógicos personalizados
#
# **Clave parcial (esquema):**
# 3. Formalización: \( (d_6 \rightarrow (p \land d_3)) \land \neg primo \)
# 6. Conclusión: "Algunos cuadrados son rombos" (Silogismo de la tercera figura)
# 8b) Ejemplo: Existencia del punto de intersección entre rectas paralelas
#
# **¿Requiere ajustar el enfoque hacia algún área específica de interés de Camilo?** Puedo adaptarlo a geometría, álgebra o teoría de números según sus necesidades.

# %% [markdown]
# # Parcial 1 para Diego Andrés Rohenes
#
# ### **Examen Parcial 1: Fundamentos de Lógica Matemática**
# **Estudiante: Diego Andrés Rohenes**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Análisis Conceptual** (15 puntos)
# 1. **(5 pts)** Demuestre mediante **equivalencias lógicas** (sin tablas de verdad):
#    \[
#    \neg(p \leftrightarrow q) \equiv (p \land \neg q) \lor (\neg p \land q)
#    \]
#    *Justifique cada paso con la ley lógica aplicada.*
#
# 2. **(5 pts)** Para las proposiciones:
#    - \( p \): "El número \( n \) es divisible por 3"
#    - \( q \): "La suma de los dígitos de \( n \) es divisible por 3"
#    a) Formalice: *"Un número es divisible por 3 si y solo si la suma de sus dígitos lo es"*
#    b) Demuestre por **contradicción** que \( p \leftrightarrow q \) es tautología.
#
# 3. **(5 pts)** Analice la validez del argumento usando **árboles semánticos**:
#    \[
#    \frac{p \rightarrow q, \neg q \lor r, \neg r}{\therefore \neg p}
#    \]
#
# ---
#
# #### **II. Lógica Aplicada a Teoría de Números** (20 puntos)
# 4. **(8 pts)** En el contexto de números primos:
#    - \( P(x) \): "\( x \) es primo"
#    - \( M(x,y) \): "\( x \) es múltiplo de \( y \)"
#    a) Formalice en lógica de predicados:
#    *"Todo número mayor que 1 tiene algún divisor primo"*
#    b) Demuestre que \( \neg \exists x (x > 1 \land \forall y (P(y) \rightarrow \neg M(x,y))) \)
#
# 5. **(6 pts)** Demuestre usando **equivalencias algebraicas**:
#    \[
#    (p \rightarrow q) \land (\neg p \rightarrow r) \equiv q \lor r
#    \]
#
# 6. **(6 pts)** Aplique **inferencia lógica** para derivar:
#    Premisa 1: Todo número perfecto es par o impar
#    Premisa 2: 28 es número perfecto
#    Premisa 3: 28 no es impar
#    Conclusión: __________________________
#
# ---
#
# #### **III. Sistemas Formales** (15 puntos)
# 7. **(8 pts)** Diseñe un **sistema lógico minimalista** para teoría de conjuntos que incluya:
#    - 1 conectivo primitivo (diferente a los clásicos)
#    - 2 axiomas sobre pertenencia e inclusión
#    - 1 regla de inferencia no estándar
#    *Ejemplifique con un teorema sobre unión de conjuntos*
#
# 8. **(7 pts)** Meta-análisis:
#    Analice el siguiente principio desde tres perspectivas:
#    *"El principio del tercero excluido en lógica clásica vs. intuicionista"*
#    a) Formalice ambas posturas
#    b) Proponga un caso en teoría de números donde sea relevante esta diferencia
#
# ---
#
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Rigor en demostraciones        | 25 pts      |
# | Creatividad en sistemas        | 15 pts      |
# | Profundidad en análisis        | 10 pts      |
#
# ### **Diseñado para Diego Andrés**:
# - **Enfoque teórico-abstracto**: Problemas de fundamentos lógicos
# - **Aplicación avanzada**: Vinculación con teoría de números y conjuntos
# - **Componente investigativo**: Construcción de sistemas originales
#
# **Clave parcial (esquema):**
# 1. Usar equivalencia del bicondicional + Leyes de De Morgan
# 4b) Refutación: contradice el Teorema Fundamental de la Aritmética
# 6. Conclusión: "28 es par" (Silogismo disyuntivo)
# 7. Ejemplo: Sistema con conectivo "es subconjunto propio"
#
# **¿Requiere mayor énfasis en algún área específica?** Puedo ajustar hacia:
# ✓ Lógica algebraica
# ✓ Teoría de demostraciones
# ✓ Aplicaciones en análisis matemático

# %% [markdown]
# # Parcial 1 de Dairo
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Dairo**
# **Fecha:** _______________
# **Duración:** 80 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Comprensión Conceptual** (15 puntos)
# 1. **(4 pts)** Defina con ejemplos:
#    - **Proposición simple** vs. **compuesta** (ejemplo matemático y cotidiano)
#    - ¿Por qué es importante la **Ley de Contradicción** en matemáticas?
#
# 2. **(5 pts)** Relacione cada ley lógica con su aplicación práctica:
#    ```
#    a) Ley de Identidad        1) "Si x = 5, entonces x = 5"
#    b) Ley de De Morgan        2) "No (A y B) = No A o No B"
#    c) Doble Negación          3) "No es cierto que no aprobé = Aprobé"
#    ```
#
# 3. **(6 pts)** Simbolice y simplifique:
#    *"Si estudio y practico, entonces aprendo; pero si no estudio, no aprendo"*
#
# ---
#
# #### **II. Lógica Aplicada** (20 puntos)
# 4. **(8 pts)** Contexto deportivo:
#    - p: "Entreno diariamente"
#    - q: "Me lesiono"
#    - r: "Juego el partido"
#    a) Traduzca: *"Si entreno diariamente y no me lesiono, entonces juego el partido"*
#    b) Construya su tabla de verdad completa
#
# 5. **(6 pts)** Demuestre usando equivalencias:
#    \[
#    \neg(p \lor q) \rightarrow r \equiv (p \lor q) \lor r
#    \]
#
# 6. **(6 pts)** Aplique inferencia:
#    Premisa 1: Si es fin de semana, voy al estadio
#    Premisa 2: Si voy al estadio, compro boletas
#    Premisa 3: No compré boletas
#    Conclusión: _______________
#
# ---
#
# #### **III. Análisis y Creación** (15 puntos)
# 7. **(7 pts)** Construya un argumento válido sobre hábitos de estudio (3 premisas + conclusión) que use:
#    - Al menos dos conectivos lógicos diferentes
#    - Una regla de inferencia clara
#
# 8. **(8 pts)** Analice este argumento:
#    *"Si corro diariamente, mejoro mi resistencia. No mejoré mi resistencia, entonces no corrí diariamente"*
#    a) ¿Es válido? Justifique
#    b) ¿Qué regla o falacia se aplicó?
#
# ---
#
# ### **Criterios de Evaluación**
# | **Habilidad**            | **Puntaje** |
# |--------------------------|-------------|
# | Claridad conceptual      | 15 pts      |
# | Precisión técnica        | 20 pts      |
# | Creatividad lógica       | 15 pts      |
#
# ### **Diseñado para Dairo**:
# - **Enfoque práctico**: Ejemplos de deportes y vida diaria
# - **Dificultad gradual**: Desde conceptos básicos hasta argumentación
# - **Espacio amplio**: Para desarrollo de tablas y demostraciones
#
# **Clave parcial (esquema):**
# 3. Simbolización: (e ∧ p) → a ∧ (¬e → ¬a)
# 6. Conclusión: "No es fin de semana" (Modus Tollens)
# 8a) Válido (Modus Tollens correctamente aplicado)
#
# **¿Necesita ajustar algún ítem para enfocarlo en algún tema específico?** Puedo adaptarlo a:
# ✓ Lógica en informática
# ✓ Aplicaciones matemáticas básicas
# ✓ Contextos laborales

# %% [markdown]
# # Parcial 1 de Jhon Sebastian
#
# ### **Examen Parcial 1: Fundamentos de Lógica**
# **Estudiante: Jhon Sebastian**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Análisis Conceptual** (15 puntos)
# 1. **(5 pts)** Demuestre mediante **equivalencias lógicas** (sin tablas de verdad):
#    \[
#    (p \rightarrow q) \land (\neg p \rightarrow r) \equiv q \lor r
#    \]
#    *Justifique cada paso con la ley lógica aplicada.*
#
# 2. **(5 pts)** Para las proposiciones:
#    - \( p \): "El número \( n \) es divisible por 6"
#    - \( q \): "\( n \) es par"
#    - \( r \): "\( n \) es divisible por 3"
#    a) Formalice: *"Un número divisible por 6 es par y divisible por 3"*
#    b) Demuestre por **contradicción** que \( p \rightarrow (q \land r) \) es tautología.
#
# 3. **(5 pts)** Analice la validez del argumento usando **árboles semánticos**:
#    \[
#    \frac{p \rightarrow q, \neg q \lor r, \neg r}{\therefore \neg p}
#    \]
#
# ---
#
# #### **II. Lógica Aplicada** (20 puntos)
# 4. **(8 pts)** En teoría de conjuntos:
#    - \( A \): "Conjunto de números pares"
#    - \( B \): "Conjunto de números divisibles por 4"
#    a) Formalice en lógica de predicados: *"Todo número divisible por 4 es par"*
#    b) Demuestre usando álgebra de Boole que:
#    \[
#    B \subseteq A
#    \]
#
# 5. **(6 pts)** Demuestre usando **equivalencias algebraicas**:
#    \[
#    \neg(p \land q) \rightarrow r \equiv p \rightarrow (\neg q \lor r)
#    \]
#
# 6. **(6 pts)** Aplique **inferencia lógica** para derivar:
#    Premisa 1: Si un triángulo es equilátero, entonces es isósceles
#    Premisa 2: El triángulo ABC no es isósceles
#    Conclusión: __________________________
#
# ---
#
# #### **III. Sistemas Lógicos** (15 puntos)
# 7. **(8 pts)** Diseñe un **sistema axiomático mínimo** para lógica geométrica que incluya:
#    - 2 conectivos lógicos primitivos
#    - 2 axiomas sobre relaciones entre figuras
#    - 1 regla de inferencia no convencional
#    *Ejemplifique con teoremas básicos de geometría*
#
# 8. **(7 pts)** Meta-análisis:
#    Analice desde perspectiva clásica e intuicionista:
#    *"En geometría euclidiana, dos rectas paralelas o se intersecan o no se intersecan"*
#    a) Formalice ambas posturas
#    b) Explique las implicaciones en cada sistema lógico
#
# ---
#
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Rigor en demostraciones        | 20 pts      |
# | Creatividad en sistemas        | 15 pts      |
# | Profundidad en análisis        | 15 pts      |
#
# ### **Diseñado para Jhon Sebastian**:
# - **Enfoque teórico-práctico**: Combina fundamentos con aplicaciones matemáticas
# - **Nivel intermedio-avanzado**: Problemas que requieren abstracción con soporte concreto
# - **Componente creativo**: Construcción de sistemas lógicos personalizados
#
# **Clave parcial (esquema):**
# 1. Usar equivalencia de implicación y distribución
# 4b) \( \forall x (x \in B \rightarrow x \in A) \)
# 6. Conclusión: "ABC no es equilátero" (Modus Tollens)
# 7. Ejemplo: Sistema con conectivo "es congruente" y axiomas de incidencia
#
# **¿Requiere ajustar el enfoque hacia geometría, álgebra o teoría de números?** Puedo adaptarlo según necesidades específicas.

# %% [markdown]
# # Parcial 1 de Simón
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Simón**
# **Fecha:** _______________
# **Duración:** 80 minutos
# **Puntaje total:** 50 puntos
#
# ---
#
# #### **I. Comprensión Conceptual** (15 puntos)
# 1. **(5 pts)** Defina con ejemplos propios:
#    - **Tabla de verdad** (construya una para p ∧ q)
#    - **Equivalencia lógica** vs **Implicación lógica**
#
# 2. **(5 pts)** Relacione cada falacia con su ejemplo:
#    ```
#    a) Afirmar el consecuente     1) "Si llueve, la calle se moja. La calle está mojada → Llueve"
#    b) Negar el antecedente       2) "Si estudio, aprobaré. No estudié → No aprobaré"
#    c) Falsa dicotomía            3) "O eres bueno en lógica o eres mal estudiante"
#    ```
#
# 3. **(5 pts)** Formalice y simplifique:
#    *"No es cierto que si juego fútbol entonces no estudio o no hago tareas"*
#
# ---
#
# #### **II. Lógica Aplicada** (20 puntos)
# 4. **(8 pts)** Contexto académico:
#    - p: "Asisto a clases"
#    - q: "Hago ejercicios"
#    - r: "Apruebo el curso"
#    a) Traduzca: *"Asisto a clases y hago ejercicios solo si apruebo el curso"*
#    b) Determine si es tautología/contradicción/contingencia mediante tabla
#
# 5. **(6 pts)** Demuestre usando álgebra lógica:
#    \[
#    (p → q) ∧ (q → r) ≡ (¬r → ¬p)
#    \]
#
# 6. **(6 pts)** Aplique **inferencia**:
#    Premisa 1: Si es martes, hay taller de lógica
#    Premisa 2: Hoy no hay taller de lógica
#    Conclusión: _______________
#
# ---
#
# #### **III. Análisis Crítico** (15 puntos)
# 7. **(8 pts)** Diseñe un **argumento válido** sobre videojuegos (3 premisas + conclusión) que use:
#    - Al menos 3 conectivos lógicos diferentes
#    - 2 reglas de inferencia (identifíquelas)
#
# 8. **(7 pts)** Analice este argumento:
#    *"Si duermo bien, rindo en exámenes. Rendí en el examen → Dormí bien"*
#    a) ¿Es válido? Justifique formalmente
#    b) ¿Qué error lógico contiene?
#
# ---
#
# ### **Criterios de Evaluación**
# | **Habilidad**            | **Puntaje** |
# |--------------------------|-------------|
# | Claridad conceptual      | 15 pts      |
# | Precisión técnica        | 20 pts      |
# | Creatividad argumental   | 15 pts      |
#
# ### **Diseñado para Simón**:
# - **Enfoque dinámico**: Ejemplos de videojuegos y vida académica
# - **Dificultad progresiva**: Desde conceptos básicos hasta argumentación compleja
# - **Espacio para desarrollo**: Áreas amplias para demostraciones
#
# **Clave parcial (esquema):**
# 3. Formalización: ¬(f → (¬e ∨ ¬t)) ≡ f ∧ (e ∧ t)
# 6. Conclusión: "Hoy no es martes" (Modus Tollens)
# 8a) No válido (falacia de afirmar el consecuente)
#
# **¿Necesita ajustar el enfoque hacia programación, matemáticas u otro ámbito?** Puedo personalizarlo completamente.

# %% [markdown]
# # Parcial 1 para Fabier Polanco
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Favier Polanco**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 60 puntos
#
# ---
#
# #### **I. Análisis Conceptual** (20 puntos)
# 1. **(6 pts)** Demuestre mediante **equivalencias lógicas** (sin tablas):
#    \[
#    (p \rightarrow q) \land (r \rightarrow s) \equiv (\neg q \lor \neg s) \rightarrow (\neg p \lor \neg r)
#    \]
#    *Justifique cada paso con la ley aplicada.*
#
# 2. **(6 pts)** Para:
#    - \( p \): "El algoritmo es eficiente"
#    - \( q \): "El tiempo es O(n log n)"
#    - \( r \): "Usa divide y vencerás"
#    a) Formalice: *"Si un algoritmo es eficiente, tiene tiempo O(n log n) solo si usa divide y vencerás"*
#    b) Demuestre por **contradicción** que \( (p \rightarrow q) \rightarrow r \) no es tautología.
#
# 3. **(8 pts)** Analice con **árboles semánticos**:
#    \[
#    \frac{p \leftrightarrow q, \neg q \lor r, \neg r}{\therefore \neg p}
#    \]
#
# ---
#
# #### **II. Lógica Computacional** (25 puntos)
# 4. **(9 pts)** En complejidad algorítmica:
#    - \( P(n) \): "El problema es solucionable en P"
#    - \( NP(n) \): "El problema está en NP"
#    a) Formalice: *"Un problema está en NP pero no en P implica P ≠ NP"*
#    b) Demuestre que \( \neg \forall n (NP(n) \rightarrow P(n)) \rightarrow P \neq NP \)
#
# 5. **(8 pts)** Optimización lógica:
#    Dado el circuito:
#    \[
#    (\neg p \lor q) \land (p \lor \neg r) \land (r \lor s)
#    \]
#    a) Simplifique usando álgebra de Boole
#    b) Diseñe la tabla de verdad optimizada
#
# 6. **(8 pts)** Inferencia aplicada:
#    Premisa 1: Si es NP-completo, es NP-hard
#    Premisa 2: SAT es NP-completo
#    Premisa 3: El problema X no es NP-hard
#    Conclusión: __________________________
#
# ---
#
# #### **III. Sistemas Formales** (15 puntos)
# 7. **(9 pts)** Diseñe un **sistema lógico computacional** con:
#    - 1 operador primitivo (ej: "es reducible a")
#    - 2 axiomas sobre clases de complejidad
#    - 1 regla de inferencia no clásica
#    *Ejemplifique con el Teorema de Cook-Levin*
#
# 8. **(6 pts)** Meta-análisis:
#    Analice desde lógica clásica y computacional:
#    *"La verificación es más fácil que la solución (P vs NP)"*
#    a) Formalice ambas perspectivas
#    b) Explique las implicaciones lógicas
#
# ---
#
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Rigor en demostraciones        | 25 pts      |
# | Creatividad computacional      | 20 pts      |
# | Profundidad teórica            | 15 pts      |
#
# ### **Diseñado para Favier Polanco**:
# - **Enfoque computacional**: Problemas de teoría de la computación
# - **Nivel avanzado**: Vinculación con complejidad algorítmica
# - **Componente innovador**: Diseño de sistemas lógicos aplicados
#
# **Clave parcial (esquema):**
# 1. Usar equivalencias de implicación y leyes de De Morgan
# 4b) Usar definiciones de clases de complejidad
# 6. Conclusión: "X no es NP-completo" (Modus Tollens + Silogismo)
# 7. Ejemplo: Sistema con operador de reducción polinomial
#
# **¿Requiere mayor énfasis en algún área específica?** Puedo adaptarlo a:
# ✓ Lógica en inteligencia artificial
# ✓ Verificación formal de software
# ✓ Teoría de lenguajes formales

# %% [markdown]
# # Parcial 1 para Jhonatan García
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Jhonatan García**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 60 puntos
#
# ---
#
# #### **I. Análisis Conceptual** (20 puntos)
# 1. **(6 pts)** Demuestre mediante **equivalencias lógicas** (sin tablas de verdad):
#    \[
#    (p \rightarrow q) \land (r \rightarrow s) \equiv (\neg q \lor \neg s) \rightarrow (\neg p \lor \neg r)
#    \]
#    *Justifique cada paso con la ley lógica aplicada.*
#
# 2. **(6 pts)** Para las proposiciones:
#    - \( p \): "El algoritmo es óptimo"
#    - \( q \): "Su complejidad es O(n log n)"
#    - \( r \): "Usa recursión"
#    a) Formalice: *"Un algoritmo es óptimo solo si tiene complejidad O(n log n) y usa recursión"*
#    b) Demuestre por **contradicción** que \( p \rightarrow (q \land r) \) es tautología.
#
# 3. **(8 pts)** Analice la validez del argumento usando **árboles semánticos**:
#    \[
#    \frac{p \leftrightarrow q, \neg q \lor r, \neg r}{\therefore \neg p}
#    \]
#
# ---
#
# #### **II. Lógica Computacional** (25 puntos)
# 4. **(9 pts)** En teoría de grafos:
#    - \( C(g) \): "El grafo g es conexo"
#    - \( A(g) \): "El grafo g es acíclico"
#    - \( T(g) \): "El grafo g es árbol"
#    a) Formalice en lógica de predicados: *"Todo grafo conexo y acíclico es árbol"*
#    b) Demuestre que \( \forall g ((C(g) \land A(g)) \rightarrow T(g)) \)
#
# 5. **(8 pts)** Optimización lógica:
#    Dado el circuito booleano:
#    \[
#    (\neg p \lor q) \land (p \lor \neg r) \land (r \lor s)
#    \]
#    a) Simplifique usando álgebra de Boole
#    b) Diseñe la tabla de verdad optimizada
#
# 6. **(8 pts)** Aplique **inferencia lógica** para derivar:
#    Premisa 1: Si un problema es NP-completo, entonces es NP-hard
#    Premisa 2: SAT es NP-completo
#    Premisa 3: El problema X no es NP-hard
#    Conclusión: __________________________
#
# ---
#
# #### **III. Sistemas Formales** (15 puntos)
# 7. **(9 pts)** Diseñe un **sistema lógico minimalista** para teoría de grafos que incluya:
#    - 1 conectivo primitivo (ej: "es adyacente a")
#    - 2 axiomas sobre propiedades de grafos
#    - 1 regla de inferencia no convencional
#    *Ejemplifique con el Teorema de Euler*
#
# 8. **(6 pts)** Meta-análisis:
#    Analice desde lógica clásica e intuicionista:
#    *"En todo grafo, el número de vértices de grado impar es par"*
#    a) Formalice ambas posturas
#    b) Explique las implicaciones en cada sistema
#
# ---
#
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Rigor en demostraciones        | 25 pts      |
# | Creatividad en sistemas        | 20 pts      |
# | Profundidad en análisis        | 15 pts      |
#
# ### **Diseñado para Jhonatan García**:
# - **Enfoque computacional**: Problemas de teoría de grafos y algoritmos
# - **Nivel avanzado**: Vinculación con complejidad computacional
# - **Componente innovador**: Diseño de sistemas lógicos aplicados
#
# **Clave parcial (esquema):**
# 1. Usar equivalencia de implicación y leyes de De Morgan
# 4b) Por definición de árbol en teoría de grafos
# 6. Conclusión: "X no es NP-completo" (Modus Tollens + Silogismo)
# 7. Ejemplo: Sistema con conectivo "es incidente a" y axiomas de grados
#
# **¿Requiere mayor énfasis en lógica difusa, inteligencia artificial u otro tema?** Puedo adaptarlo completamente.

# %% [markdown]
# # Parcial 1 para  Eliecer
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Eliecer**
# **Fecha:** _______________
# **Duración:** 90 minutos = 1.5 horas
# **Puntaje total:** 60 puntos
#
# ---

# %% [markdown]
# #### **I. Comprensión Conceptual** (18 puntos)
# 1. **(6 pts)** Demuestre mediante **equivalencias lógicas**:
#    $$
#    \neg(p \leftrightarrow q) \equiv (p \lor q) \land \neg(p \land q)
#    $$
#    *Justifique cada paso con la ley aplicada (Leyes de De Morgan, Doble Negación, etc.)*

# %% [markdown]
# \begin{align*}
# \neg(p \leftrightarrow q)  & \equiv \neg[(p \rightarrow q) \land (q \rightarrow p)]  \quad \text{Definición alterna del bicondicional}\\
# & \equiv \neg[(\neg p \lor q) \land (\neg q \lor p)]  \quad \text{Definición de implicación}\\
# & \equiv \neg(\neg p \lor q) \lor \neg(\neg q \lor p)  \quad \text{Ley de De Morgan}\\
# & \equiv (p \land \neg q) \lor (q \land \neg p)  \quad \text{Ley de De Morgan}\\
# \end{align*}
#
# Fundamentado en la página 25 del Libro Matemáticas I de Lina Grajales. Tema sobre Reglas de la Lógica.

# %%
from sympy import symbols, Equivalent

def verificar_equivalencia(propo1, propo2):
    """
    Verifica si dos proposiciones lógicas son equivalentes.

    Args:
        propo1: Una proposición lógica en formato sympy. ~ para negar >> para implicación, & para conjunción, | para disyunción.
        propo2: Otra proposición lógica en formato sympy.

    Returns:
        bool: True si las proposiciones son equivalentes, False en caso contrario.
    """
    return bool(Equivalent(propo1, propo2))

# Ejemplo de uso
if __name__ == "__main__":
    # Definir variables lógicas
    p, q = symbols('p q')
    
    # Proposiciones de ejemplo
    proposicion1 = ~((p >> q) & (q >> p))
    proposicion2 = (p | q) & ~(p & q)
    
    # Verificar equivalencia
    resultado = verificar_equivalencia(proposicion1, proposicion2)
    print(f"¿Son equivalentes? {resultado}")
# Out:
# ¿Son equivalentes? True

# %% [markdown]
# # Probemos otro camino de demostración
#
# \begin{align*}
# \neg(p ↔ q) & \equiv \neg p ↔ q \quad \quad \text{Negación del bicondicional}\\
# & () \land () \quad \quad \text{Definición alterna del bicondicional}\\
# \end{align*}

# %% [markdown]
# 2. **(6 pts)** Para las proposiciones:
#    - $ p $: "El sistema es estable"
#    - $ q $: "Los autovalores tienen parte real negativa"
#    - $ r $: "La matriz es definida positiva"
#    a) Formalice: *"El sistema es estable si y solo si los autovalores tienen parte real negativa, excepto cuando la matriz es definida positiva"*
#    b) Determine si $(p \leftrightarrow q) \land \neg r $ es contingencia

# %% [markdown]
# 3. **(6 pts)** Analice con **tablas de verdad extendidas**:
#    $$
#    (p \rightarrow q) \lor (r \land \neg q)
#    $$
#    ¿Para qué valores de $ p, q, r $ la proposición es falsa?
#
# ---

# %% [markdown]
# #### **II. Lógica Aplicada a Sistemas** (24 puntos)
# 4. **(8 pts)** En control automático:
#    - $ C(s) $: "El sistema en lazo cerrado es estable"
#    - $P(s)$: "El polo está en el semiplano izquierdo"
#    - $ K $: "La ganancia es positiva"
#    a) Formalice: *"Para que el sistema en lazo cerrado sea estable, todos los polos deben estar en el semiplano izquierdo y la ganancia ser positiva"*
#    b) Demuestre que $\forall s (C(s) \rightarrow (P(s) \land K))$

# %% [markdown]
# ### **Contextualización de la Lógica Proposicional en el Problema**
#
# En este ejercicio, se aplica la **lógica proposicional** para formalizar enunciados relacionados con el control automático de sistemas. La lógica proposicional nos permite traducir afirmaciones del lenguaje natural a expresiones lógicas precisas, utilizando conectores como **∧ (AND)**, **∨ (OR)**, **→ (implicación)**, etc.
#
# ### **Parte a) Formalización del Enunciado**
#
# **Enunciado original:**
# *"Para que el sistema en lazo cerrado sea estable, todos los polos deben estar en el semiplano izquierdo y la ganancia ser positiva."*
#
# #### **Paso 1: Identificar las proposiciones atómicas**
# - $ C(s) $: "El sistema en lazo cerrado es estable" (depende de $s$ porque la estabilidad se evalúa para cada polo $s$).
# - $ P(s) $: "El polo $s$ está en el semiplano izquierdo".
# - $ K $: "La ganancia es positiva" (no depende de $s$).
#
# #### **Paso 2: Traducir la estructura lógica**
# La frase tiene la forma de una condición necesaria:
# *"Para que $C(s)$ sea verdadero, es necesario que $P(s)$ y $K$ sean verdaderos."*
# Esto equivale a:
# *"Si $C(s)$ es verdadero, entonces $P(s)$ y $K$ deben ser verdaderos."*
#
# En lógica proposicional, se formaliza como:
# $$ C(s) \rightarrow (P(s) \land K). $$
#
# #### **Paso 3: Generalizar para todos los polos**
# Como el enunciado dice *"todos los polos"*, debemos cuantificar universalmente sobre $s$:
# $$ \forall s \, (C(s) \rightarrow (P(s) \land K)). $$
#
# **Nota:** Aquí hay un detalle importante. Si $C(s)$ ya representa "el sistema es estable" (que depende de todos los polos), entonces la formalización correcta podría ser:
# $$ C \rightarrow (\forall s \, P(s) \land K), $$
# donde $C$ ya no depende de $s$. Depende de cómo se definan las proposiciones.
#
# Pero el enunciado parece sugerir que $C(s)$ depende de cada polo $s$, por lo que la primera interpretación es válida.
#
# ---
#
# ### **Parte b) Demostración de la Fórmula**
#
# **Fórmula a demostrar:**
# $$ \forall s \, (C(s) \rightarrow (P(s) \land K)). $$
#
# #### **Estrategia de Demostración**
# Para demostrar una implicación universal ($\forall s \, (\phi \rightarrow \psi)$), se asume $\phi$ como hipótesis y se deduce $\psi$ para un $s$ arbitrario.
#
# 1. **Hipótesis:** Sea $s$ un polo arbitrario. Asumimos $C(s)$ (el sistema es estable para este polo).
# 2. **Objetivo:** Probar $P(s) \land K$ (el polo $s$ está en el semiplano izquierdo y la ganancia es positiva).
#
# #### **Paso 1: Estabilidad en Sistemas de Control**
# En control automático, un sistema en lazo cerrado es estable **si y solo si**:
# - Todos sus polos están en el semiplano izquierdo ($\forall s \, P(s)$).
# - La ganancia $K$ no causa inestabilidad (en muchos casos, $K > 0$ es una condición necesaria).
#
# #### **Paso 2: Aplicar la Definición de Estabilidad**
# Si $C(s)$ es verdadero (el sistema es estable para el polo $s$), entonces:
# - El polo $s$ debe estar en el semiplano izquierdo ($P(s)$).
# - La ganancia $K$ debe ser positiva (de lo contrario, el sistema podría ser inestable).
#
# Por lo tanto, $P(s) \land K$ se cumple.
#
# #### **Paso 3: Generalización**
# Como $s$ era arbitrario, la implicación vale para todo $s$:
# $$ \forall s \, (C(s) \rightarrow (P(s) \land K)). $$
#
# ---
#
# ### **Conclusión**
# - La formalización correcta del enunciado es la implicación universal dada.
# - La demostración se basa en las propiedades de estabilidad de sistemas dinámicos: la estabilidad requiere que todos los polos estén en el semiplano izquierdo y que la ganancia sea positiva.
#
# **Posible Corrección:**
# Si $C$ representa la estabilidad global del sistema (no por polo), la formalización sería:
# $$ C \rightarrow (\forall s \, P(s) \land K), $$
# y la demostración sería similar, pero basada en la estabilidad global.
#
# El ejercicio parece usar $C(s)$ como una propiedad por polo, por lo que la primera interpretación es válida.

# %% [markdown]
# 5. **(8 pts)** Optimización lógica:
#    Simplifique el circuito booleano:
#    $$
#    (\neg p \lor q) \land (p \lor \neg r) \land (r \lor s)
#    $$
#    a) Mediante álgebra de Boole
#    b) Mediante mapa de Karnaugh
#
# 6. **(8 pts)** Aplique **inferencia lógica** para derivar:
#    Premisa 1: Si el controlador es PID, el error en estado estacionario es cero
#    Premisa 2: Si el error es cero, el sistema es estable
#    Premisa 3: El sistema no es estable
#    Conclusión: __________________________
#
# ---
#
# #### **III. Sistemas Dinámicos y Lógica** (18 puntos)
# 7. **(10 pts)** Diseñe un **sistema lógico para control automático** que incluya:
#    - 1 operador modal ("siempre")
#    - 2 axiomas sobre estabilidad
#    - 1 regla de inferencia temporal
#    *Ejemplifique con un sistema de segundo orden*
#
# 8. **(8 pts)** Meta-análisis:
#    Analice desde lógica clásica y modal:
#    *"Un sistema es estable si eventualmente todos sus estados convergen"*
#    a) Formalice ambas perspectivas
#    b) Explique las diferencias en interpretación
#
# ---
#
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Rigor matemático               | 24 pts      |
# | Aplicación en sistemas         | 24 pts      |
# | Creatividad formal             | 12 pts      |
#
# ### **Diseñado para Eliecer**:
# - **Enfoque en sistemas dinámicos**: Vinculación con control automático
# - **Nivel avanzado**: Incorpora lógica modal y temporal
# - **Componente práctico**: Optimización de circuitos lógicos
#
# **Clave parcial (esquema):**
# 1. Usar equivalencia del bicondicional + Leyes de De Morgan
# 4b) Por definición de estabilidad en sistemas de control
# 6. Conclusión: "El controlador no es PID" (Modus Tollens + Silogismo)
# 7. Ejemplo: Sistema con operador □ para "siempre estable"
#
# **¿Requiere mayor énfasis en algún área específica?** Puedo adaptarlo a:
# ✓ Lógica difusa en control
# ✓ Sistemas híbridos
# ✓ Verificación formal de sistemas

# %% [markdown]
# # Parcial 1 para Fabiar Urda (Simonelly)
#
# ### **Examen Parcial: Fundamentos de Lógica**
# **Estudiante: Fabián Silva Urda (Simonneelly)**
# **Fecha:** _______________
# **Duración:** 90 minutos
# **Puntaje total:** 60 puntos
#
# ---

# %% [markdown]
# #### **I. Lógica Proposicional Avanzada** (20 puntos)
# 1. **(8 pts)** Optimización de circuitos lógicos:
#    Dada la expresión:
#    \[
#    (\neg p \land q) \lor (p \land \neg r) \lor (q \land r)
#    \]
#    a) Simplifíquela usando álgebra de Boole (muestre todos los pasos)
#    b) Diseñe el circuito lógico optimizado
#
# 2. **(6 pts)** Demuestre mediante **equivalencias lógicas**:
#    $$
#    p \rightarrow (q \lor r) \equiv (p \land \neg q) \rightarrow r
#    $$
#    *Justifique cada paso con la ley aplicada*
#
# 3. **(6 pts)** Análisis semántico:
#    Para la fórmula:
#    $$
#    (p \leftrightarrow q) \land (\neg q \lor r)
#    $$
#    Determine todos los valores de verdad de \( p, q, r \) que hacen falsa la expresión
#
# ---

# %% [markdown]
# #### **II. Aplicaciones en Sistemas Inteligentes** (24 puntos)
# 4. **(8 pts)** En inteligencia artificial:
#    - \( P \): "El agente percibe el entorno"
#    - \( Q \): "El agente toma una decisión óptima"
#    - \( R \): "El sistema tiene aprendizaje reforzado"
#    a) Formalice: *"El agente toma decisiones óptimas si y solo si percibe el entorno y el sistema tiene aprendizaje reforzado"*
#    b) Demuestre que \( (P \land R) \leftrightarrow Q \) no es tautología

# %% [markdown]
# 5. **(8 pts)** Inferencia en sistemas expertos:
#    Premisa 1: Si es un día laboral, el sistema usa reglas estrictas
#    Premisa 2: Si es fin de semana, el sistema usa reglas flexibles
#    Premisa 3: Hoy no es día laboral
#    Conclusión: __________________________
#    *Justifique con reglas de inferencia*

# %% [markdown]
# 6. **(8 pts)** Lógica difusa:
#    Dadas las funciones de pertenencia:
#    - \( \mu_A(x) = 0.7 \)
#    - \( \mu_B(x) = 0.4 \)
#    Calcule y explique:
#    a) $\mu_{A \cap B}(x)$ (usando mínimo)
#    b) \( \mu_{A \cup B}(x) \) (usando máximo)
#
# ---
#
# #### **III. Sistemas Complejos** (16 puntos)
# 7. **(10 pts)** Diseñe un **sistema lógico para IoT** que incluya:
#    - 1 operador temporal ("eventualmente")
#    - 2 axiomas sobre conectividad
#    - 1 regla de inferencia para fallos
#    *Ejemplifique con un caso de smart home*

# %% [markdown]
# 8. **(6 pts)** Meta-análisis:
#    Compare desde lógica clásica y difusa:
#    *"Un sensor está funcionando correctamente"*
#    a) Formalice ambas perspectivas
#    b) Explique ventajas de cada enfoque
#
# ---

# %% [markdown]
# ### **Criterios de Evaluación**
# | **Competencia**               | **Puntaje** |
# |--------------------------------|-------------|
# | Precisión técnica              | 24 pts      |
# | Aplicación en IA/Sistemas      | 24 pts      |
# | Innovación en diseños          | 12 pts      |
#
# ### **Diseñado para Fabián Silva Urda (Simonneelly)**:
# - **Enfoque en inteligencia artificial**: Aplicaciones prácticas en IA y IoT
# - **Nivel avanzado**: Combina lógica clásica y difusa
# - **Componente innovador**: Diseño de sistemas inteligentes
#
# **Clave parcial (esquema):**
# 1. Simplificación: $(q \land \neg r) \lor (p \land \neg r) \lor (q \land r)$
# 4b) Contraejemplo: \( P=V, Q=F, R=V \) hace falsa la equivalencia
# 5. Conclusión: "El sistema usa reglas flexibles" (Silogismo disyuntivo)
# 7. Ejemplo: Sistema con operador ◇ para "eventualmente conectado"
#
# **¿Necesita ajustar el enfoque hacia robótica, big data u otra área?** Puedo personalizarlo completamente.

# %% [markdown]
# ## **10. Retroalimentación**
# - Rúbrica de autoevaluación con criterios: *"Claridad en la demostración", "Uso de herramientas STEAM"*.
#
# ---

# %% [markdown]
# ## **11. Vocabulario Inglés**
# - **Proof/Demostración**, **Axiom/Axioma**, **Theorem/Teorema**, *"Q.E.D. (Quod Erat Demonstrandum)"*.
#
# ---
#
# ## **12. Apéndice: Habilidades Blandas**
# - Técnicas para trabajo en equipo: *"Escucha activa en discusiones de demostraciones"*.
# - Inteligencia Emocional: *"Manejo de ansiedad en evaluaciones"*.
#
# ---

# %% [markdown]
# ## **13. Referentes APA**
# 1. Duval, R. (2006). *A cognitive analysis of problems of comprehension in the learning of mathematics*. Educational Studies in Mathematics, 61(1-2), 103-131.
# 2. Wing, J. M. (2006). *Computational thinking*. Communications of the ACM, 49(3), 33-35.
# ... *(lista completa en el diseño extendido)*.
#
# ---
# **Nota:** Este diseño integra ABPP, STEAM y herramientas interactivas para un aprendizaje experimental. ¡Ajusta los paths y URLs según tu entorno!

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Jupyter Book de fundamentos_logica](file:///C:/Users/marco/Documentos/docencia/fundamentos_logica/fundamentos_logica_book/_build/html/index.html)
#
#
# * [Decargue Crocodile Clip aquí](https://crocodileclips.net/descargar-crocodile-clips/)
#
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://github.com/marco-canas/fundamentos_de_la_aritmetica/blob/main/referentes/2_grajales_logica/grajales_lina_matemticas.pdf)
#
# * Duval, R. (2004). Semiosis y pensamiento humano: registros semióticos y aprendizajes intelectuales. Universidad del Valle.
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](https://github.com/marco-canas/fundamentos_logica/blob/main/referentes/2_uzcategui/uscategui.pdf)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/chollet/Fran%C3%A7ois%20Chollet%20-%20Deep%20Learning%20with%20Python-Manning%20(2018).pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/geron/Hands-On%20Machine%20Learning-3nd_Edition(2022).pdf)
#
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/mckinney/Wes_McKinney.pdf)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()
